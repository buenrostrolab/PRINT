# %%
import h5py
import copy
import anndata as ad
import numpy as np
import scanpy as sc
import pandas as pd
import seaborn as sns
import os
from tqdm.auto import trange, tqdm
import matplotlib.pyplot as plt
from spectra.spectra import spectra_util as spc_tl
from spectra.spectra import spectra as spc

# %%
def check_gene_set_dictionary(adata, annotations, obs_key='cell_type',global_key='global', return_dict = True):
    '''
    Filters annotations dictionary contains only genes contained in the adata. 
    Checks that annotations dictionary cell type keys and adata cell types are identical.
    Checks that all gene sets in annotations dictionary contain >2 genes after filtering.
    
    adata: AnnData , data to use with Spectra
    annotations: dict , gene set annotations dictionary to use with Spectra
    obs_key: str , column name for cell type annotations in adata.obs
    global_key: str , key for global gene sests in gene set annotation dictionary
    return_dict: bool , return filtered gene set annotation dictionary
    
    returns: dict , filtered gene set annotation dictionary
    
    '''
    #test if keys match
    adata_labels  = list(set(adata.obs[obs_key]))+['global']#cell type labels in adata object
    annotation_labels = list(annotations.keys())
    matching_celltype_labels = list(set(adata_labels).intersection(annotation_labels))
    if set(annotation_labels)==set(adata_labels):
        print('Cell type labels in gene set annotation dictionary and AnnData object are identical')
        dict_keys_OK = True
    if len(annotation_labels)<len(adata_labels):
        print('The following labels are missing in the gene set annotation dictionary:',set(adata_labels)-set(annotation_labels))
        dict_keys_OK = False
    if len(adata_labels)<len(annotation_labels):
        print('The following labels are missing in the AnnData object:',set(annotation_labels)-set(adata_labels))
        dict_keys_OK = False
        
    #check that gene sets in dictionary have len >2
    Counter = 0
    annotations_new = {}
    for k,v in tqdm(annotations.items()):
        annotations_new[k] = {}
        for k2,v2 in v.items():
            annotations_new[k][k2]= [x for x in v2 if x in adata.var_names]
            length = len(v2)
            if length<3:
                print('gene set',k2,'for cell type',k,'is of length',length)
                Counter = Counter+1
            
    if Counter > 0:
        print(Counter,'gene sets are too small. Gene sets must contain at least 3 genes')
    elif Counter == 0 and dict_keys_OK:
        print('Your gene set annotation dictionary is correctly formatted.')
    if return_dict:
        return annotations_new

# %%
# Load scRNA data
h5_path = "../../data/mHSCAging10xSubpopulation/scRNA.h5"
hf = h5py.File(h5_path, 'r')
RNA_matrix = hf.get('RNA_matrix')[:, :]
UMAP = hf.get('UMAP')[:, :]
barcodes = hf.get('barcodes')
genes = hf.get('genes')
barcodes = [bc.decode('ascii') for bc in barcodes]
genes = [g.decode('ascii') for g in genes]
hf.close()

# %%
# Initialize AnnData object
adata = ad.AnnData(RNA_matrix)
adata.obs_names = barcodes
adata.var_names = genes
adata.obs["cell_type"] = ["HSC"] * len(barcodes)
adata.obsm["X_umap"] = UMAP.T
adata.obsm["ATAC_umap"] = UMAP.T
# Out:
# /tmp/ipykernel_1996644/2961747691.py:2: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   adata = ad.AnnData(RNA_matrix)

# %%
import re
age = [re.split("-", i)[1] for i in list(adata.obs.index)]
adata.obs['age'] = age

# %%
sc.pl.umap(adata, color=['age'])
# Out:
# /n/holylfs05/LABS/buenrostro_lab/Users/yanhu/.conda/envs/PRINT/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
annotations = spc_tl.get_default_dict()
annotations["HSC"] = {}
marker_dir = "../../data/mHSCAging10xSubpopulation/markers/RNA/"
marker_files = [i for i in os.listdir(marker_dir) if re.search("txt", i)]
marker_names = [i.replace(".txt", "") for i in marker_files]
for marker_ind in range(len(marker_names)):
    annotations["HSC"][marker_names[marker_ind]] = list(pd.read_table(
        "../../data/mHSCAging10xSubpopulation/markers/RNA/" + marker_files[marker_ind],header=None).iloc[:, 0].values)
    
# Convert human genes to mouse genes
for pathway in annotations["global"]:
    annotations["global"][pathway] = [g.capitalize() for g in annotations["global"][pathway]]
    
# Only keep HSC and global gene sets
annotations = {key: annotations[key] for key in ["HSC", "global"]}

# Filter gene sets
annotations = check_gene_set_dictionary(adata, annotations, obs_key='cell_type', global_key='global')
for cell_type in ["HSC", "global"]:
    gene_sets = copy.deepcopy(list(annotations[cell_type].keys()))
    for gene_set in gene_sets:
        if len(annotations[cell_type][gene_set]) < 5:
            del annotations[cell_type][gene_set]
# Out:
# Cell type labels in gene set annotation dictionary and AnnData object are identical
#   0%|          | 0/2 [00:00<?, ?it/s]
# Your gene set annotation dictionary is correctly formatted.

# %%
#fit the model (We will run this with only 2 epochs to decrease runtime in this tutorial)
model = spc.est_spectra(adata = adata, gene_set_dictionary = annotations, 
                        use_highly_variable = False, cell_type_key = "cell_type", 
                        use_weights = True, lam = 0.01, 
                        delta=0.001,kappa = 0.00001, rho = 0.00001, 
                        use_cell_types = True, n_top_vals = 50, 
                        label_factors = True, #whether to label the factors by their overlap coefficient with the input gene sets
                        overlap_threshold = 0.2, #minimum overlap coefficient that has to be surpassed to assign a label to a factor
                        num_epochs=1000 #for demonstration purposes we will only run 2 epochs, we recommend 10,000 epochs
                       )
# Out:
# 100%|██████████| 1000/1000 [35:36<00:00,  2.14s/it]

# %%
adata.write_h5ad("../../data/mHSCAging10xSubpopulation/spectra/spectra_adata.h5ad")

# %%
adata = ad.read_h5ad("../../data/mHSCAging10xSubpopulation/spectra/spectra_adata.h5ad")

# %%
# Get markers
factor_markers = adata.uns['SPECTRA_markers']
factor_markers = pd.DataFrame(factor_markers).T
factor_markers.columns = adata.uns['SPECTRA_overlap'].index

# Write markers to file
path = "../../data/mHSCAging10xSubpopulation/spectra/spectra_markers.tsv"
factor_markers.to_csv(path, sep = "\t", index=False)

# %%
factor_markers
# Out:
#    0-X-global-X-all_biotin_metabolism 1-X-global-X-all_purine_synthesis  \
# 0                             Slc16a1                               Ak1
# 1                                Hlcs                               Ada
# 2                              Slc5a6                               Ak4
# 3                               Acss1                              Aprt
# 4                            Hsd17b10                              Guk1
# 5                             Gm42418                               Ak3
# 6                                 Btd                               Gda
# 7                                 Hal                              Itpa
# 8                                 Ogt                             Gmpr2
# 9                             Cbfa2t3                             Ampd3
# 10                             Ccdc58                             Nt5c2
# 11                               Nemf                               Adk
# 12                               Xpo1                               Ak2
# 13                             Diaph1                             Ampd2
# 14                               Vcan                              Gmpr
# 15                             Plscr1                            Slc2a9
# 16                               Arsb                           Slc28a2
# 17                               Faf1                               Hal
# 18                             Iqgap2                           Csnk1a1
# 19                            Csnk1a1                               Xdh
# 20                             Ube2l6                              Xpo1
# 21                            Serinc1                           Csnk2a1
# 22                            Csnk2a1                           Slc29a2
# 23                              Ireb2                               Ogt
# 24                            Tbl1xr1                               Ak5
# 25                              Tbl1x                              Nt5e
# 26                             Tgfbr3                             Edem2
# 27                               Mtdh                             Srsf6
# 28                               Gpd2                           Cbfa2t3
# 29                              Chrm3                              Faf1
# 30                              Edem2                              Nemf
# 31                               Bphl                             Ube2k
# 32                             Ube2g1                            Ube2g1
# 33                             Rsl1d1                           Tbl1xr1
# 34                             Ranbp1                             Ifrd1
# 35                               Rora                             Dgcr8
# 36                              Itga6                            Tbc1d5
# 37                                Ncl                             Cul4a
# 38                               Usp7                             Nop53
# 39                                Por                              Vta1
# 40                              Ifrd1                             Cdc26
# 41                             Exosc7                            Dnmt3a
# 42                             Tmsb4x                            Anapc5
# 43                              Ube2k                            Rmnd5a
# 44                               Cop1                              Mtm1
# 45                               Ostc                              Ogdh
# 46                             Anapc5                            Dnmt3b
# 47                           Rap1gds1                             Znrf1
# 48                               Tsr1                              Arsb
# 49                             Fbxl20                             Sdcbp
#
#    2-X-global-X-all_amino-sugar-nucleotide-sugar_metabolism  \
# 0                                                Cmas
# 1                                               Gfpt1
# 2                                                Uxs1
# 3                                                Uap1
# 4                                                 Gne
# 5                                              Gnpda2
# 6                                                Nagk
# 7                                             Gnpnat1
# 8                                              Uap1l1
# 9                                                Nans
# 10                                             Gnpda1
# 11                                             Mansc1
# 12                                              Renbp
# 13                                             Amdhd2
# 14                                               Tgds
# 15                                              Gfpt2
# 16                                               Gale
# 17                                               Pgm3
# 18                                                Hal
# 19                                               Arsb
# 20                                            Csnk1a1
# 21                                            Csnk2a1
# 22                                               Xpo1
# 23                                                Ogt
# 24                                              Ube2k
# 25                                              Edem2
# 26                                               Nemf
# 27                                            Cbfa2t3
# 28                                            Tbl1xr1
# 29                                                Esd
# 30                                              Ifrd1
# 31                                               Hlcs
# 32                                               Faf1
# 33                                             Stat5a
# 34                                             Tbc1d5
# 35                                               Vcan
# 36                                             Ube2g1
# 37                                               Klf6
# 38                                             Dnmt3a
# 39                                              Cul4a
# 40                                               Vta1
# 41                                               Ogdh
# 42                                              Nop53
# 43                                              Cdc26
# 44                                              Dgcr8
# 45                                                Pkm
# 46                                             Anapc5
# 47                                             Rmnd5a
# 48                                             Dnmt3b
# 49                                               Mtm1
#
#    3-X-global-X-all_steroid_metabolism 4-X-global-X-all_carnitine-shuttle  \
# 0                              Slco3a1                              Cpt1a
# 1                                Abcc1                           Slc25a20
# 2                                Abcc4                               Cpt2
# 3                                Soat1                            Slc22a5
# 4                              Sult1a1                               Crat
# 5                               Dhcr24                              Cpt1c
# 6                                Fdft1                              Cpt1b
# 7                               Hmgcs1                            Slc22a4
# 8                                Msmo1                            Cbfa2t3
# 9                               Stard3                               Arsb
# 10                                Sqle                                Tst
# 11                                Sc5d                             Ccdc58
# 12                                Scp2                             Sephs2
# 13                            Hsd17b12                              Kmt5a
# 14                                Pmvk                              Decr1
# 15                              Srd5a1                            Ldhal6b
# 16                               Nsdhl                               Hadh
# 17                                 Lss                              Acadl
# 18                                 Ebp                                Ogt
# 19                             Hsd17b7                                Por
# 20                               Ggps1                                Hal
# 21                                 Mvk                               Xpo1
# 22                                 Mvd                            Csnk1a1
# 23                             Slco4a1                             Metap1
# 24                             Hsd11b1                            Serinc1
# 25                             Cyp11a1                               Cryz
# 26                             Sult2b1                              Erp29
# 27                              Tm7sf2                              Hsdl2
# 28                             Slc25a1                              Edem2
# 29                                Fdps                             Ube2g1
# 30                            Rap1gds1                             Anapc5
# 31                                Arsb                            Csnk2a1
# 32                              Pabpc1                              Ube2k
# 33                                Gpd2                            Tbl1xr1
# 34                               Atxn1                               Nemf
# 35                                 Ide                               Faf1
# 36                               Cpeb2                              Hibch
# 37                              Ccdc58                              Ifrd1
# 38                                Vcan                             Tbc1d5
# 39                               Pcyt2                              Dock1
# 40                                Xpo1                             Rmnd5a
# 41                                Pck2                              Cdc26
# 42                              Stard4                             Ube2l6
# 43                             Csnk1a1                            Cox7a2l
# 44                             Csnk2a1                              Cul4a
# 45                                 Ogt                               Vta1
# 46                               Alcam                              Dgcr8
# 47                             Aldh3a2                              Kyat1
# 48                                Ostc                              Srsf6
# 49                              Antxr2                              Nop53
#
#    5-X-global-X-all_TLR_signaling 6-X-global-X-all_phosphoinositide_signaling  \
# 0                            Akt3                                       Plcl1
# 1                            Tab2                                        Ocrl
# 2                           Irak1                                        Pten
# 3                            Rac1                                      Inpp5d
# 4                          Map2k4                                       Plcb4
# 5                           Mapk1                                       Plcb2
# 6                          Mapk14                                      Inpp4b
# 7                          Ifnar2                                       Plcg2
# 8                          Pik3r1                                       Synj1
# 9                            Akt2                                     Pip5k1b
# 10                         Map2k2                                       Itpkb
# 11                            Jun                                       Plcb1
# 12                         Pik3ca                                      Inpp5a
# 13                          Stat1                                       Inpp1
# 14                         Pik3cd                                      Pik3r1
# 15                         Map2k3                                      Inpp5b
# 16                         Map2k7                                      Inpp4a
# 17                         Map2k1                                     Pik3c2a
# 18                         Map2k6                                      Pik3ca
# 19                          Irak4                                     Pip5k1a
# 20                           Akt1                                      Pik3cd
# 21                          Traf3                                     Pip5k1c
# 22                         Pik3cg                                      Pik3cg
# 23                         Tollip                                       Plcb3
# 24                           Tlr4                                       Synj2
# 25                          Mapk9                                        Hcst
# 26                            Fos                                      Inppl1
# 27                          Mapk8                                      Inpp5e
# 28                          Nfkb1                                      Plcxd2
# 29                            Lbp                                       Plcg1
# 30                          Traf6                                      Pik3cb
# 31                         Ifnar1                                       Mtmr3
# 32                           Tab1                                      Pik3r2
# 33                         Pik3cb                                       Itpka
# 34                         Map3k7                                       Plcd3
# 35                         Ticam1                                       Plch1
# 36                          Mapk3                                       Itpkc
# 37                           Irf5                                     Pik3c2b
# 38                         Nfkbia                                      Pik3r5
# 39                          Tirap                                      Pik3r3
# 40                         Pik3r2                                      Pik3c3
# 41                          Myd88                                       Ywhab
# 42                          Il12a                                        Cltc
# 43                          Ikbkb                                       Mknk1
# 44                           Cd86                                     Csnk1a1
# 45                           Ly96                                      Akt1s1
# 46                           Tlr6                                       Ube2n
# 47                           Spp1                                     Csnk2a1
# 48                         Ticam2                                       Itpr2
# 49                           Tbk1                                         Ogt
#
#    7-X-global-X-all_microautophagy-lysosomal 8-X-global-X-all_TCA-cycle  \
# 0                                       Atg7                       Sdha
# 1                                     Tbc1d5                       Aco2
# 2                                    Atp13a2                       Ogdh
# 3                                    Gm42418                       Mdh1
# 4                                      Atg13                       Sdhc
# 5                                    Cbfa2t3                      Pdha1
# 6                                      Atg2a                       Mdh2
# 7                                     Rb1cc1                       Pdhb
# 8                                      Atg2b                     Sucla2
# 9                                    Csnk2a1                      Idh3b
# 10                                   Snrnp70                      Idh3g
# 11                                     Hspa8                       Idh1
# 12                                       Ogt                         Cs
# 13                                   Csnk1a1                       Idh2
# 14                                     Tomm6                       Sdhb
# 15                                    Eef1a1                      Idh3a
# 16                                      Xpo1                       Pdp1
# 17                                      Mtm1                       Pdhx
# 18                                      Vta1                      Cpt1a
# 19                                      Nemf                       Aco1
# 20                                   Tbl1xr1                   Rap1gds1
# 21                                     Ube2k                      Kmt5a
# 22                                      Vmp1                       Gpd2
# 23                                     Edem2                        Por
# 24                                      Faf1                       Arsb
# 25                                    Ube2g1                     Ndufv1
# 26                                     Ifrd1                      Hsdl2
# 27                                    Prkag2                    Aldh3a2
# 28                                     Rab1a                      Decr1
# 29                                      Ctsa                      Vdac3
# 30                                      Smg1                       Hadh
# 31                                     Cul4a                        Nbn
# 32                                     Rragc                      Uqcrh
# 33                                     Ilrun                       Bphl
# 34                                     Dgcr8                       Mpc1
# 35                                     Cdc26                    Csnk1a1
# 36                                      Pfn1                    Cox7a2l
# 37                                   Atg16l1                     Ndufa4
# 38                                     Nop53                      Hsph1
# 39                                      Ogdh                     Polr2f
# 40                                   Slc38a9                        Ogt
# 41                                     Rab43                       Xpo1
# 42                                    Rmnd5a                      Mlycd
# 43                                    Anapc5                    Csnk2a1
# 44                                       Vcp                       Ostc
# 45                                    Zfyve1                     Ndufv2
# 46                                     Vps36                        Auh
# 47                                     Qsox1                     Ndufs1
# 48                                    Akap13                      Cyb5a
# 49                                     Vps35                    Serinc1
#
#    9-X-global-X-all_lipophagy  ... 132-X-global-X-all_IL6-JAK-STAT3_signaling  \
# 0                      Sptlc2  ...                                       Pim1
# 1                      Sptlc1  ...                                      Stat3
# 2                       Adrb2  ...                                      Itga4
# 3                       Sesn2  ...                                       Grb2
# 4                     Csnk2a1  ...                                        Cbl
# 5                      Eef1a1  ...                                       Cd44
# 6                         Htt  ...                                        Ltb
# 7                     Csnk1a1  ...                                        Jun
# 8                        Xpo1  ...                                      Stat1
# 9                         Ogt  ...                                     Il17ra
# 10                     Tbc1d5  ...                                      Itgb3
# 11                       Aup1  ...                                      Ptpn1
# 12                    Snrnp70  ...                                      Ptpn2
# 13                       Vta1  ...                                      Csf3r
# 14                      Ube2k  ...                                     Ifngr1
# 15                       Mtm1  ...                                   Tnfrsf21
# 16                    Tbl1xr1  ...                                       Irf9
# 17                      Edem2  ...                                      Stam2
# 18                       Nemf  ...                                      Stat2
# 19                     Ube2g1  ...                                      Crlf2
# 20                    Cbfa2t3  ...                                        Cd9
# 21                      Ifrd1  ...                                       Tyk2
# 22                       Faf1  ...                                      Il2rg
# 23                      Rab1a  ...                                       Bak1
# 24                     Zfyve1  ...                                     Ifnar1
# 25                      Rragc  ...                                       Ltbr
# 26                      Cul4a  ...                                       Irf1
# 27                      Nop53  ...                                      Il3ra
# 28                      Cdc26  ...                                      Pdgfc
# 29                       Ogdh  ...                                       Ebi3
# 30                     Anapc5  ...                                     Il18r1
# 31                     Rmnd5a  ...                                        Pf4
# 32                     Prkag2  ...                                      Myd88
# 33                      Exoc4  ...                                      Il1r1
# 34                      Dgcr8  ...                                     Csf2ra
# 35                       Vmp1  ...                                     Acvr1b
# 36                      Qsox1  ...                                   Tnfrsf1b
# 37                        Vcp  ...                                   Tnfrsf1a
# 38                      Hspa8  ...                                     Ptpn11
# 39                      Srsf6  ...                                      Tgfb1
# 40                       Pfn1  ...                                      Il6st
# 41                      Znrf1  ...                                       Osmr
# 42                       Spop  ...                                      Il1r2
# 43                      Rptor  ...                                       Csf1
# 44                       Cln3  ...                                     Map3k8
# 45                      Psmd1  ...                                       Hax1
# 46                      Sumo2  ...                                       Cd36
# 47                      Rab43  ...                                     Csf2rb
# 48                    Slc38a9  ...                                       Il9r
# 49                      Ube2h  ...                                    Il12rb1
#
#    133-X-global-X-all_autophagy-chaperone-mediated 134-X-global-X-134  \
# 0                                           Eef1a1              Dach1
# 1                                         Hsp90aa1              Elmo1
# 2                                          Snrnp70              Lrmda
# 3                                            Hspa8             Adgrl4
# 4                                            Lamp2              Mecom
# 5                                           Synpo2              Nrxn1
# 6                                             Snca               Msi2
# 7                                            Stub1              Mctp1
# 8                                             Ctsa               Aff3
# 9                                              Clu              Foxp1
# 10                                            Plk3              Prkg1
# 11                                            Bag3           Arhgap15
# 12                                         Atp13a2              Mbnl1
# 13                                         Gm42418             Samd12
# 14                                        Rap1gds1              Foxn3
# 15                                          Iqgap2             Ripor2
# 16                                             Ogt             Pard3b
# 17                                         Cbfa2t3             Immp2l
# 18                                          Tgfbr3           Mir99ahg
# 19                                          Hectd1             Zbtb20
# 20                                         Csnk1a1               Etv6
# 21                                          Akap13              Meis1
# 22                                          Rnasel                Fau
# 23                                            Xpo1             Malat1
# 24                                            Arf1             Angpt1
# 25                                           Arpc5           AY036118
# 26                                         Tbl1xr1               Tpt1
# 27                                         Csnk2a1             Fchsd2
# 28                                            Nemf            Gm42418
# 29                                          Ube2l6             Zfp608
# 30                                           Edem2              Rbm39
# 31                                            Faf1               Utrn
# 32                                            Grk2              Tcf12
# 33                                           Ube2k             Cacnb2
# 34                                           Anxa5               Pan3
# 35                                          Akt1s1               Pbx1
# 36                                         Mapkap1              Trpc6
# 37                                          Ube2g1              Baz2b
# 38                                          Fbxl17              Smyd3
# 39                                           Alcam               Dlg2
# 40                                           Hmgb1           Kcnq1ot1
# 41                                           Mknk1             Kansl1
# 42                                           Uqcrh              Igf1r
# 43                                           Hdac1              Celf2
# 44                                          Cab39l              Runx1
# 45                                            Eif1             Luc7l2
# 46                                          Tbc1d5              Ssbp2
# 47                                        Ppp1r12a               Cux1
# 48                                            Usp7              Nipbl
# 49                                            Cfl1            Fam172a
#
#    135-X-global-X-Rodriguez_Fraticelli_et_al_multilineage  \
# 0                                             Hnrnph1
# 1                                                Npm1
# 2                                                Btf3
# 3                                               H2afz
# 4                                                 Set
# 5                                                Ybx1
# 6                                                Oaz1
# 7                                              Hnrnpf
# 8                                           Hnrnpa2b1
# 9                                              Chchd2
# 10                                               Hdgf
# 11                                             Tuba1b
# 12                                                Ran
# 13                                              Actr3
# 14                                               Ppia
# 15                                             Atpif1
# 16                                              Snrpf
# 17                                                Myb
# 18                                               Smc2
# 19                                             Atp5g3
# 20                                               Mcm3
# 21                                             Snrpd1
# 22                                              Nolc1
# 23                                              Psma1
# 24                                                Dtl
# 25                                               Mcm7
# 26                                              Uhrf1
# 27                                            Fam117a
# 28                                               Mcm4
# 29                                           AI506816
# 30                                              Cks1b
# 31                                               Tfrc
# 32                                             Alyref
# 33                                              Pdss1
# 34                                               Rcc1
# 35                                            Tmem14c
# 36                                              Ddx39
# 37                                              Cdca8
# 38                                             Fignl1
# 39                                              Ap3s1
# 40                                               Nkg7
# 41                                               Sell
# 42                                               Ctse
# 43                                              Ms4a3
# 44                                               Calr
# 45                                             Prss57
# 46                                             Cited4
# 47                                             Hbb-bs
# 48                                               Flt3
# 49                                              Nop56
#
#    136-X-global-X-Pei_et_al_differentiation_inactive  \
# 0                                              Sgms1
# 1                                             Med12l
# 2                                               Nrgn
# 3                                               Gbp7
# 4                                             Gas2l3
# 5                                              Mmrn1
# 6                                              Cpne8
# 7                                               Msi2
# 8                                              Aplp2
# 9                                              Grb10
# 10                                               Mt1
# 11                                              Apoe
# 12                                              Jund
# 13                                             Cyp51
# 14                                             Slfn2
# 15                                            Zfp873
# 16                                              Bex1
# 17                                             Erp27
# 18                                             Hoxb2
# 19                                          Slc25a33
# 20                                            H2-Eb1
# 21                                           Gm42418
# 22                                            Serbp1
# 23                                             Pnisr
# 24                                              Naca
# 25                                            Eef1b2
# 26                                              Myl6
# 27                                           Hnrnpa3
# 28                                             Mylip
# 29                                          Il1rapl1
# 30                                              Chd4
# 31                                             Tubb5
# 32                                            Dazap2
# 33                                              Arf5
# 34                                           Zfp36l2
# 35                                          BC005537
# 36                                              Cd63
# 37                                             Myct1
# 38                                           Serinc3
# 39                                             H3f3b
# 40                                              Sfpq
# 41                                            Hnrnpk
# 42                                            Polr1b
# 43                                            Ifitm1
# 44                                              Cdk8
# 45                                             Taco1
# 46                                            Nap1l1
# 47                                              Rbm3
# 48                                            Jarid2
# 49                                            Luc7l3
#
#    137-X-global-X-Pei_et_al_multilineage  \
# 0                                Gm42418
# 1                               AY036118
# 2                                  Lars2
# 3                                 Malat1
# 4                                Gm26917
# 5                                 Camk1d
# 6                                Gm48099
# 7                                Gm20594
# 8                                  Cmss1
# 9                                   Ptma
# 10                               Gm15564
# 11                                  Cdk8
# 12                                Angpt1
# 13                                  Tpt1
# 14                                 Kpna1
# 15                                 Stmn1
# 16                                Jarid2
# 17                                   Fau
# 18                                 H2afy
# 19                                  Cd34
# 20                                  Lsp1
# 21                                 Ifi27
# 22                             Serpinb1a
# 23                                 Plac8
# 24                                Gm5111
# 25                                  Cd53
# 26                                  Fut7
# 27                                  Gmfg
# 28                                   Vim
# 29                                  Tap2
# 30                                Ctla2a
# 31                                  Rif1
# 32                                 H3f3b
# 33                               Serinc3
# 34                                 Taco1
# 35                                  Rbm3
# 36                                Adgrl4
# 37                                Serbp1
# 38                                 Gcnt2
# 39                                Hnrnpk
# 40                                  Car2
# 41                             Hnrnpa2b1
# 42                                  Sfpq
# 43                               Zfp36l2
# 44                                Nap1l1
# 45                                  Chd4
# 46                                  Jund
# 47                                Znhit1
# 48                              BC005537
# 49                                Luc7l3
#
#    138-X-global-X-Rodriguez_Fraticelli_et_al_mkBiased  \
# 0                                               H2-K1
# 1                                                 B2m
# 2                                                Lmo2
# 3                                                 Hlf
# 4                                               Txnip
# 5                                              Ifitm1
# 6                                               Mllt3
# 7                                               Ccnd2
# 8                                                Cbx6
# 9                                                Uba7
# 10                                              Mecom
# 11                                               Msi2
# 12                                             Pik3r1
# 13                                              Mmrn1
# 14                                               Cd63
# 15                                              Ptk2b
# 16                                              Gng11
# 17                                           Pdzk1ip1
# 18                                              Myct1
# 19                                               Mycn
# 20                                          Serpina3g
# 21                                            Tspan14
# 22                                           Tmem176b
# 23                                               Jund
# 24                                              Aplp2
# 25                                              Iigp1
# 26                                              Grb10
# 27                                               Def8
# 28                                             Trim47
# 29                                             Clec1a
# 30                                             S100a6
# 31                                              Matn4
# 32                                               Ly6a
# 33                                               Art4
# 34                                              Procr
# 35                                               Apoe
# 36                                               Selp
# 37                                               Lyz2
# 38                                            Sec14l1
# 39                                            Col16a1
# 40                                                Ryk
# 41                                             Slamf1
# 42                                              Nupr1
# 43                                               Fhl1
# 44                                              Enpp5
# 45                                             Unc45b
# 46                                             S100a9
# 47                                              Wdpcp
# 48                                               Bex1
# 49                                               Bex4
#
#    139-X-global-X-Rodriguez_Fraticelli_et_al_highOutput  \
# 0                                               H3f3a
# 1                                              Anp32b
# 2                                               Cmtm7
# 3                                             Hnrnpab
# 4                                             Irf2bp2
# 5                                               Ramp1
# 6                                                Plek
# 7                                               Cox5a
# 8                                              Itga2b
# 9                                                 Myc
# 10                                              Crip1
# 11                                             Tmsb10
# 12                                           Sh3bgrl3
# 13                                              Banf1
# 14                                             Lgals9
# 15                                               Rfc2
# 16                                               Mcm2
# 17                                              Hmgn5
# 18                                             Adgrg3
# 19                                              H2afz
# 20                                                Set
# 21                                               Cd37
# 22                                               Ybx1
# 23                                               Oaz1
# 24                                              Parvg
# 25                                            Slc25a5
# 26                                             Hnrnpf
# 27                                          Hnrnpa2b1
# 28                                             Chchd2
# 29                                               Hdgf
# 30                                              Syce2
# 31                                             Tuba1b
# 32                                                Ran
# 33                                               Ppia
# 34                                             Mfsd2b
# 35                                             Atpif1
# 36                                              Ffar2
# 37                                              Snrpf
# 38                                                Myb
# 39                                              Anxa2
# 40                                                Nrm
# 41                                               Bin1
# 42                                             Atp5g3
# 43                                               Aqp1
# 44                                              Gata1
# 45                                              Golm1
# 46                                               Mcm7
# 47                                               Palm
# 48                                            Fam117a
# 49                                               Mcm4
#
#    140-X-global-X-Rodriguez_Fraticelli_et_al_lowOutput 141-X-global-X-141
# 0                                              Tbxas1                Cdk8
# 1                                               Nedd4               Cmss1
# 2                                              Eif4a2             Gm48099
# 3                                               H2-D1              Jarid2
# 4                                               H2-Q7               Kpna1
# 5                                                Myof             Gm15564
# 6                                             Laptm4a                Rbm3
# 7                                               Abcg3               Taco1
# 8                                                Fgd5                Rcc2
# 9                                               H2-Q4                Arf5
# 10                                           Tmem176a                Nono
# 11                                             Gimap8            BC005537
# 12                                              Ccnd1               Prtn3
# 13                                             Scarf1               Srsf1
# 14                                             Casp12              Hnrnpk
# 15                                          Gabarapl1               Gata2
# 16                                              H2-Aa              Cavin2
# 17                                              Fstl1               Srsf2
# 18                                             Fkbp1a               Snrpe
# 19                                               Ctsl              Nucks1
# 20                                                Ndn               Srsf3
# 21                                               Ppic               Pfdn5
# 22                                               Mylk            Arhgap45
# 23                                              Tcf15              Atp5a1
# 24                                      D630039A03Rik       2900097C17Rik
# 25                                                Ltb              Nap1l1
# 26                                               F11r               Numa1
# 27                                               Jam3                 Tsn
# 28                                              Myl10               Snhg8
# 29                                               Cish             Hnrnph2
# 30                                              Gstm1               G3bp1
# 31                                              Mmrn1              Zfand5
# 32                                              Grb10                Purb
# 33                                              Aplp2              Eif4g2
# 34                                               Bex1               Tra2b
# 35                                             H2-Eb1               Celf1
# 36                                             Serbp1                Myl6
# 37                                              Pnisr                Srgn
# 38                                               Naca               Eif4b
# 39                                             Eef1b2              Ptp4a2
# 40                                               Myl6              Dazap2
# 41                                            Hnrnpa3              Camk1d
# 42                                              H2-K1             Gm26917
# 43                                              Mylip             Tmem30a
# 44                                            Gm42418               Rbbp4
# 45                                           Il1rapl1               Serf2
# 46                                                B2m                Sfpq
# 47                                             Ifitm1               Srsf5
# 48                                              Ccnd2          AC149090.1
# 49                                               Chd4               Eif3a
#
# [50 rows x 142 columns]

# %%
score_sums = np.sum(adata.obsm['SPECTRA_cell_scores'], axis = 0)
top_programs = np.where(score_sums > np.percentile(score_sums, 75))[0]

# Cluster cells by program scores
plt_df = pd.DataFrame(data = adata.obsm['SPECTRA_cell_scores'][:, top_programs], 
                      columns = np.array(adata.uns['SPECTRA_overlap'].index.tolist())[top_programs])

row_colors = pd.Series(["#E31B23" if a == "Old" else "#003366" for a in age])
sns.clustermap(plt_df, standard_scale = 1, row_colors=row_colors)
plt.savefig("../../data/mHSCAging10xSubpopulation/spectra/top_program_clustermap.png")
# Out:
# /n/holylfs05/LABS/buenrostro_lab/Users/yanhu/.conda/envs/PRINT/lib/python3.8/site-packages/seaborn/matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)

# %%
score_mat = adata.obsm['SPECTRA_cell_scores']
sns.clustermap(np.corrcoef(score_mat.T), 
               cmap = "vlag", 
               col_colors = ["r" if i == 27 else "b" for i in range(factor_markers.shape[1])])

# %%
plt.scatter(
    adata.obsm['X_umap'][:, 0],
    adata.obsm['X_umap'][:, 1],
    s = 1,
    c = adata.obsm['SPECTRA_cell_scores'][:, 134],
    cmap = "Reds"
)

# %%
factor_markers.iloc[:, 138]
# Out:
# 0       Gm42418
# 1      AY036118
# 2         Lars2
# 3        Malat1
# 4          Msi2
# 5       Gm26917
# 6       Gm20594
# 7        Ifitm1
# 8       Gm48099
# 9        Camk1d
# 10        Cmss1
# 11     Pdzk1ip1
# 12         Uba7
# 13       Angpt1
# 14         Jund
# 15        Ccnd2
# 16        H2-K1
# 17          Fau
# 18        Gng11
# 19         Apoe
# 20        Grb10
# 21      Serinc3
# 22    Serpina3g
# 23         Mycn
# 24       S100a6
# 25       Trim47
# 26       Clec1a
# 27        H3f3b
# 28      Sult1a1
# 29        Nupr1
# 30         Esam
# 31         Bex4
# 32       Cdkn1c
# 33       Zbtb20
# 34       Clec4g
# 35        Meis1
# 36        Mbnl1
# 37      Zfp36l2
# 38         Tgm2
# 39        Runx1
# 40       H2-Eb1
# 41        Wdpcp
# 42         Tpt1
# 43         Pbx1
# 44       Akap13
# 45        Prkg1
# 46       Exosc4
# 47      Fam210b
# 48         Car2
# 49        Enpp5
# Name: 138-X-global-X-Pei_et_al_differentiation_inactive, dtype: object

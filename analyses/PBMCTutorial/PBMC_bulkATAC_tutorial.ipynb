# %%
# %load_ext autoreload
# %autoreload 2
import scprinter as scp
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import time
import pandas as pd
import numpy as np
import os
import pickle
import torch
import matplotlib as mpl
mpl.rcParams['pdf.fonttype'] = 42
from scanpy.plotting.palettes import zeileis_28
from tqdm.contrib.concurrent import *
from tqdm.auto import *
import anndata
import scanpy as sc
import json
import csv
import re
from sklearn.preprocessing import OneHotEncoder
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# In this tutorial, we will test run PRINT/seq2PRINT on bulk ATAC samples. In bulk ATAC-seq, you typically will have separate fragments files for each sample (in contrast to single-cell, where there is a single framents file with barcode labels corresponding to single cells). We recommend you use scPrinter to simply load each individual fragments file together as shown below. In the individual fragments file, each line of the barcode column populated with the name of the sample. Therefore, we are essentially treating each bulk sample as a "big cell".
#
# The dataset is a simulated bulk ATAC dataset by sampling from the 10x PBMC 5k single cell dataset. This is to help you compare and contrast with our scATAC tutorial which uses the same dataset. We similuate 2 bulk ATAC samples from each major cell type (B cell, monocyte, T cell). Although this dataset is simulated bulk-ATAC, the data format and how we run scPrinter is exactly the same as real bulk ATAC data.

# %%
main_dir = '/data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial/'
work_dir = f'{main_dir}/seq2print'
if not os.path.exists(work_dir):
    os.system("mkdir -p " + work_dir)
frag_dir = f'{main_dir}/fragments'

# %%
# Download the fragments files of bulk samples from our Zenodo repository https://zenodo.org/records/14866808 using the code below
samples = ["Bcell_0", "Bcell_1", "Monocyte_0", "Monocyte_1", "Tcell_0", "Tcell_1"]
for sample in samples:
    link_prefix = "https://zenodo.org/records/14866808/files/PBMC_bulk_ATAC_tutorial_"
    link_suffix = "_frags.tsv.gz?download=1"
    os.system(f"wget -O {frag_dir}/{sample}_frags.tsv.gz {link_prefix}{sample}{link_suffix}")

# %%
# Get the fragments files for individual samples
# Note: the fragments files should have 4 columns: chromosome, start, end, and barcode. 
# Barcode should just be sample name, which means all fragments in the same fragments file have the same barcode.
frag_files = os.listdir(frag_dir)
frag_files = [i for i in frag_files if re.search("frags.tsv.gz", i) is not None]
frag_files = sorted([os.path.join(frag_dir, i) for i in frag_files])
samples = ["_".join(re.split("[/_\\.]", i)[11:13]) for i in frag_files]
samples
# Out:
# ['Bcell_0', 'Bcell_1', 'Monocyte_0', 'Monocyte_1', 'Tcell_0', 'Tcell_1']

# %% [markdown]
# ## Create scprinter & preprocessing

# %%
printer = scp.pp.import_fragments(
                        path_to_frags=frag_files,
                        barcodes=[None] * len(frag_files), # This loads individual fragments files and combine them
                        savename=os.path.join(work_dir, 'PBMC_bulkATAC_scprinter.h5ad'),
                        genome=scp.genome.hg38,
                        min_num_fragments=1000, min_tsse=7,
                        sorted_by_barcode=False, 
                        low_memory=False,
                        )
# Out:
# Multiple fragments files detected, it is suggested to provide sample names to avoid barcode collision
# You are now using the beta auto_detect_shift function, this overwrites the plus_shift and minus_shift you provided
# If you believe the auto_detect_shift is wrong, please set auto_detect_shift=False
# Importing fragments:   0%|          | 0/6 [00:00<?, ?it/s]
# Detecting the shift in the paired end fragments file
# If you think the above message is wrong, please check the input file format
# Minimum MSE is 0.0005955448951918777, shift detected
# Minimum MSE is 0.0006030499324759502, shift detected
# detected plus_shift and minus_shift are 4 -5 for /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//fragments/Bcell_0_frags.tsv.gz
# Detecting the shift in the paired end fragments file
# If you think the above message is wrong, please check the input file format
# Minimum MSE is 0.0006028001861080011, shift detected
# Minimum MSE is 0.0006623381912235417, shift detected
# detected plus_shift and minus_shift are 4 -5 for /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//fragments/Bcell_1_frags.tsv.gz
# Detecting the shift in the paired end fragments file
# If you think the above message is wrong, please check the input file format
# Minimum MSE is 0.00014615018925039585, shift detected
# Minimum MSE is 0.00012077646791016112, shift detected
# detected plus_shift and minus_shift are 4 -5 for /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//fragments/Monocyte_0_frags.tsv.gz
# Detecting the shift in the paired end fragments file
# If you think the above message is wrong, please check the input file format
# Minimum MSE is 0.0001375292696875001, shift detected
# Minimum MSE is 0.00013275516301249993, shift detected
# detected plus_shift and minus_shift are 4 -5 for /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//fragments/Monocyte_1_frags.tsv.gz
# Detecting the shift in the paired end fragments file
# If you think the above message is wrong, please check the input file format
# Minimum MSE is 0.001023044977344454, shift detected
# Minimum MSE is 0.0010046164203803254, shift detected
# detected plus_shift and minus_shift are 4 -5 for /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//fragments/Tcell_0_frags.tsv.gz
# Detecting the shift in the paired end fragments file
# If you think the above message is wrong, please check the input file format
# Minimum MSE is 0.0009438418163786169, shift detected
# Minimum MSE is 0.0010185394360764303, shift detected
# detected plus_shift and minus_shift are 4 -5 for /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//fragments/Tcell_1_frags.tsv.gz
#   0%|          | 0/6 [00:00<?, ?it/s]
# start transferring insertions

# %%
# Rename barcodes to sample IDs
printer.insertion_file.obs_names = samples

# %%
# Generate Tn5 insertion bigwigs for each pseudobulk
scp.pp.sync_footprints(printer,
                       [[sample] for sample in samples],
                       samples)
# Out:
# Loading insertion profiles
# Creating bigwig for Bcell_0
#   0%|          | 0/24 [00:00<?, ?it/s]
# Creating bigwig for Bcell_1
#   0%|          | 0/24 [00:00<?, ?it/s]
# Creating bigwig for Monocyte_0
#   0%|          | 0/24 [00:00<?, ?it/s]
# Creating bigwig for Monocyte_1
#   0%|          | 0/24 [00:00<?, ?it/s]
# Creating bigwig for Tcell_0
#   0%|          | 0/24 [00:00<?, ?it/s]
# Creating bigwig for Tcell_1
#   0%|          | 0/24 [00:00<?, ?it/s]

# %% [markdown]
# ## Call peaks on the fragments in a preset for training seq2PRINT model

# %%
# Call peaks
scp.pp.call_peaks(printer=printer,
                  frag_file=frag_files,
                  cell_grouping=[None], # here we call peaks on the cells that are included in the final analyses
                  group_names=['all'],
                  preset='seq2PRINT')

# Fetched the cleaned peaks, save, it will be used in the next step
cleaned_peaks = pd.DataFrame(printer.uns["peak_calling"]['all_cleaned'][:])
cleaned_peaks.to_csv(f'{work_dir}/seq2print_cleaned_narrowPeak.bed', 
                     sep='\t', header=False, index=False)
cleaned_peaks.to_csv(f'{work_dir}/regions.bed', 
                     sep='\t', header=False, index=False)
# Out:
# INFO  @ Mon, 10 Feb 2025 21:41:35:
# # Command line: callpeak --nomodel -t /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//fragments/Bcell_0_frags.tsv.gz /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//fragments/Bcell_1_frags.tsv.gz /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//fragments/Monocyte_0_frags.tsv.gz /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//fragments/Monocyte_1_frags.tsv.gz /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//fragments/Tcell_0_frags.tsv.gz /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//fragments/Tcell_1_frags.tsv.gz --outdir /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/PBMC_bulkATAC_scprinter_supp/macs2 -n all -f BEDPE --nolambda --keep-dup all --call-summits --nomodel -B --SPMR --shift 75 --extsize 150 -p 0.01
# # ARGUMENTS LIST:
# # name = all
# # format = BEDPE
# # ChIP-seq file = ['/data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//fragments/Bcell_0_frags.tsv.gz', '/data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//fragments/Bcell_1_frags.tsv.gz', '/data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//fragments/Monocyte_0_frags.tsv.gz', '/data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//fragments/Monocyte_1_frags.tsv.gz', '/data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//fragments/Tcell_0_frags.tsv.gz', '/data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//fragments/Tcell_1_frags.tsv.gz']
# # control file = None
# # effective genome size = 2.70e+09
# # band width = 300
# # model fold = [5, 50]
# # pvalue cutoff = 1.00e-02
# # qvalue will not be calculated and reported as -1 in the final output.
# # The maximum gap between significant sites is assigned as the read length/tag size.
# # The minimum length of peaks is assigned as the predicted fragment length "d".
# # Larger dataset will be scaled towards smaller dataset.
# # Range for calculating regional lambda is: 10000 bps
# # Broad region calling is off
# # Paired-End mode is on
# # Searching for subpeak summits is on
# # MACS will save fragment pileup signal per million reads
#
# INFO  @ Mon, 10 Feb 2025 21:41:35: #1 read fragment files...
# INFO  @ Mon, 10 Feb 2025 21:41:35: #1 read treatment fragments...
# INFO  @ Mon, 10 Feb 2025 21:41:36:  1000000
# INFO  @ Mon, 10 Feb 2025 21:41:37:  2000000
# INFO  @ Mon, 10 Feb 2025 21:41:38:  3000000
# INFO  @ Mon, 10 Feb 2025 21:41:39:  4000000
# INFO  @ Mon, 10 Feb 2025 21:41:40:  5000000
# INFO  @ Mon, 10 Feb 2025 21:41:41:  6000000
# INFO  @ Mon, 10 Feb 2025 21:41:42:  7000000
# INFO  @ Mon, 10 Feb 2025 21:41:43:  8000000
# INFO  @ Mon, 10 Feb 2025 21:41:44:  9000000
# INFO  @ Mon, 10 Feb 2025 21:41:45:  10000000
# INFO  @ Mon, 10 Feb 2025 21:41:46:  1000000
# INFO  @ Mon, 10 Feb 2025 21:41:47:  2000000
# INFO  @ Mon, 10 Feb 2025 21:41:48:  3000000
# INFO  @ Mon, 10 Feb 2025 21:41:49:  4000000
# INFO  @ Mon, 10 Feb 2025 21:41:50:  5000000
# INFO  @ Mon, 10 Feb 2025 21:41:51:  6000000
# INFO  @ Mon, 10 Feb 2025 21:41:52:  7000000
# INFO  @ Mon, 10 Feb 2025 21:41:53:  8000000
# INFO  @ Mon, 10 Feb 2025 21:41:54:  9000000
# INFO  @ Mon, 10 Feb 2025 21:43:12: #3 Call peaks...
# INFO  @ Mon, 10 Feb 2025 21:43:12: # local lambda is disabled!
# INFO  @ Mon, 10 Feb 2025 21:43:12: #3 !!!! DYNAMIC LAMBDA IS DISABLED !!!!
# INFO  @ Mon, 10 Feb 2025 21:43:12: #3 Going to call summits inside each peak ...
# INFO  @ Mon, 10 Feb 2025 21:43:12: #3 Call peaks with given -log10pvalue cutoff: 2.00000 ...
# INFO  @ Mon, 10 Feb 2025 21:43:12: #3 Pre-compute pvalue-qvalue table...
# INFO  @ Mon, 10 Feb 2025 21:43:24: #3 In the peak calling step, the following will be performed simultaneously:
# INFO  @ Mon, 10 Feb 2025 21:43:24: #3   Write bedGraph files for treatment pileup (after scaling if necessary)... all_treat_pileup.bdg
# INFO  @ Mon, 10 Feb 2025 21:43:24: #3   Write bedGraph files for control lambda (after scaling if necessary)... all_control_lambda.bdg
# INFO  @ Mon, 10 Feb 2025 21:43:24: #3   --SPMR is requested, so pileup will be normalized by sequencing depth in million reads.
# INFO  @ Mon, 10 Feb 2025 21:43:24: #3 Call peaks for each chromosome...
# INFO  @ Mon, 10 Feb 2025 21:44:39: #4 Write output xls file... /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/PBMC_bulkATAC_scprinter_supp/macs2/all_peaks.xls
# INFO  @ Mon, 10 Feb 2025 21:44:40: #4 Write peak in narrowPeak format file... /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/PBMC_bulkATAC_scprinter_supp/macs2/all_peaks.narrowPeak
# INFO  @ Mon, 10 Feb 2025 21:44:40: #4 Write summits bed file... /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/PBMC_bulkATAC_scprinter_supp/macs2/all_summits.bed
# INFO  @ Mon, 10 Feb 2025 21:44:41: Done!
# Reading in peak summit file(s):
# NOTE: Assuming all start coordinates are 0-based ..
#
# Padding peak summits by: 500 bp on either side for
# Removing peaks overlapping with blacklisted regions and out of bound peaks based on chromosome sizes ..
#
# Filtering overlapping peaks based on peak summit score ..
# round: 1 299137 peaks unresolved 295927 peaks selected
# round: 2 146 peaks unresolved 142 peaks selected
# finish clearing
# finish sorting
# finished summary
# /tmp/ipykernel_488059/1907163871.py:9: DeprecationWarning: `Series._import_from_c` is deprecated. use _import_arrow_from_c; if you are using an extension, please compile it with latest 'pyo3-polars'
#   cleaned_peaks = pd.DataFrame(printer.uns["peak_calling"]['all_cleaned'][:])

# %% [markdown]
# ## Training separate seq2PRINT models for each sample

# %%
import json
model_configs = []
if not os.path.exists(os.path.join(work_dir, 'configs')):
    os.makedirs(os.path.join(work_dir, 'configs'))
for sample in samples:
    # For exploratory analyses we run only one fold. For publication results you can run all 5 fold for slight improvement in accuracy.
    # If you want to run all five folds, add a for-loop layer "for fold in range(5)". This way each sample will have 5 models trained.
    fold=0 
    model_config= scp.tl.seq_model_config(printer,
                                     region_path=f'{work_dir}/seq2print_cleaned_narrowPeak.bed',
                                     cell_grouping=[sample],
                                     group_names=sample,
                                     genome=printer.genome,
                                     fold=fold, 
                                     overwrite_bigwig=False,
                                     model_name='PBMC_bulkATAC_' + sample,
                                     additional_config={
                                        "notes": "v3",
                                        "tags": ["PBMC_bulkATAC", sample, 
                                            f"fold{fold}"]},
                                     path_swap=(work_dir, ''),
                                     config_save_path=f'{work_dir}/configs/PBMC_bulkATAC_{sample}_fold{fold}.JSON')
    model_configs.append(model_config)
# Out:
# bigwig for Bcell_0 already exists, skip
# bigwig for Bcell_1 already exists, skip
# bigwig for Monocyte_0 already exists, skip
# bigwig for Monocyte_1 already exists, skip
# bigwig for Tcell_0 already exists, skip
# bigwig for Tcell_1 already exists, skip

# %% [markdown]
# Below we generate the commands to run in the terminal to launch our training process (copy the generated command into a terminal and run). Before launching the training process, it is recommended to install wandb and use it to track the training process. You can first register an account on https://wandb.ai/, then you can activate your mamba/conda environment such as mamba activate scprinter, and install wandb using mamba install wandb. Then you can login via wandb login. This will connect your mamba/conda env with your wandb account. More information on wandb can be found in their quick start guide at https://docs.wandb.ai/quickstart/

# %% [markdown]
# Before running the generated commands, you can run nvtop first to check which GPUs are available. This is especially important when you share the same server with other users. The training job is rather computational intensive and usually one job could take a whole GPU. Therefore, we recommend you manually set the CUDA_VISIBLE_DEVICES in the commands to the fully free GPUs.

# %% [markdown]
# When you run the command in the terminal, make sure you are in the scprinter mamba environment. To run multiple training jobs in parallel you can add & to the end of each command, such as ```CUDA_VISIBLE_DEVICES=0 seq2print_train --config /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/configs/PBMC_bulkATAC_Bcell_0_fold0.JSON --temp_dir /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/temp --model_dir /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model --data_dir /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print --project scPrinter_seq_PBMC_bulkATAC --enable_wandb &```

# %%
for path in ['temp','model']:
    if not os.path.exists(os.path.join(work_dir, path)):
        os.makedirs(os.path.join(work_dir, path))

for sample in samples:
    scp.tl.launch_seq2print(model_config_path=f'{work_dir}/configs/PBMC_bulkATAC_{sample}_fold{fold}.JSON',
                            temp_dir=f'{work_dir}/temp',
                            model_dir=f'{work_dir}/model',
                            data_dir=work_dir,
                            gpus=samples.index(sample),
                            wandb_project='scPrinter_seq_PBMC_bulkATAC', # wandb helps you manage loggins
                            verbose=False,
                            launch=False # launch=True, this command would launch the scripts directly,
                            # otherwise, it will just display the commands, you should copy them and run them.
                           )
# Out:
# CUDA_VISIBLE_DEVICES=0 seq2print_train --config /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/configs/PBMC_bulkATAC_Bcell_0_fold0.JSON --temp_dir /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/temp --model_dir /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model --data_dir /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print --project scPrinter_seq_PBMC_bulkATAC --enable_wandb
# CUDA_VISIBLE_DEVICES=1 seq2print_train --config /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/configs/PBMC_bulkATAC_Bcell_1_fold0.JSON --temp_dir /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/temp --model_dir /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model --data_dir /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print --project scPrinter_seq_PBMC_bulkATAC --enable_wandb
# CUDA_VISIBLE_DEVICES=2 seq2print_train --config /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/configs/PBMC_bulkATAC_Monocyte_0_fold0.JSON --temp_dir /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/temp --model_dir /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model --data_dir /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print --project scPrinter_seq_PBMC_bulkATAC --enable_wandb
# CUDA_VISIBLE_DEVICES=3 seq2print_train --config /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/configs/PBMC_bulkATAC_Monocyte_1_fold0.JSON --temp_dir /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/temp --model_dir /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model --data_dir /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print --project scPrinter_seq_PBMC_bulkATAC --enable_wandb
# CUDA_VISIBLE_DEVICES=4 seq2print_train --config /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/configs/PBMC_bulkATAC_Tcell_0_fold0.JSON --temp_dir /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/temp --model_dir /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model --data_dir /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print --project scPrinter_seq_PBMC_bulkATAC --enable_wandb
# CUDA_VISIBLE_DEVICES=5 seq2print_train --config /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/configs/PBMC_bulkATAC_Tcell_1_fold0.JSON --temp_dir /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/temp --model_dir /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model --data_dir /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print --project scPrinter_seq_PBMC_bulkATAC --enable_wandb

# %% [markdown]
# ## Generate TF binding scores for each sample

# %%
# Now fetch models:
import wandb

# Login to your W&B account
wandb.login()

# Set your entity and project
entity = 'yanhu0196-harvard-university'  # Replace with your W&B entity (username or team name)
project = 'scPrinter_seq_PBMC_bulkATAC'  # Replace with your W&B project name

# Initialize the API
api = wandb.Api()

# Get the project
runs = api.runs(f"{entity}/{project}")

pretrain_models = []
model_path_dict = {}
for run in runs:
    if run.state != 'finished':
        continue
    if 'PBMC_bulkATAC' in run.tags:
        sample = [i for i in run.tags if i in samples][0]
        model_name = run.config['savename'] + '-' + run.name + '.pt'
        model_path = os.path.join(work_dir, "model", model_name)
        model_path_dict[sample] = model_path

# %%
regions_dict = {
    'chr11:47378230-47379030': 'SPI1', # Highly expressed in monocytes and B cells
    'chr5:140633035-140633835': 'CD14', # Monocyte marker
    'chr19:41876833-41877633': 'CD79a', # B cell marker
    'chr11:118342294-118343094': 'CD3D', # T cell marker
    'chr17:58281312-58282112': 'MPO', # Monocyte marker
    'chr16:31259594-31260394': 'ITGAM', # Expressed in myeloid cells (including monocyte)
    'chr3:39281281-39282081': 'CX3CR1', # A pretty important gene driving disease-related monocyte cell states
    'chr9:37033951-37034751': 'PAX5' # B cell marker
}

# Save example regions to a bed file
regions_df = []
for region in regions_dict:
    regions_df.append(re.split("[:-]", region))
regions_df = pd.DataFrame(regions_df)
regions_df.to_csv(f'{work_dir}/regions_test.bed',
                  sep='\t', header=False, index=False)

# %% [markdown]
# Below we launch the compute for TF binding scores. When we are only testing on a small number of regions or samples, we can set return_adata to be True so that the results can be returned also in an anndata object. If the number of regions or samples is big please set it to False so it doesn't take up all the memory.

# %% [markdown]
# Remember to check nvtop to select available GPUs using the "gpus" argument.

# %%
import json
adata_tfbs = {}
for sample_ind, sample in enumerate(samples):
    adata_tfbs[sample] = scp.tl.seq_tfbs_seq2print(seq_attr_count=None,
                          seq_attr_footprint=None,
                          genome=printer.genome,
                          region_path=f'{work_dir}/regions_test.bed',
                          gpus=[1,2,3],
                          model_type='seq2print',
                          model_path=model_path_dict[sample], # For now we just run on one fold but you can provide a list of paths to all 5 folds
                          lora_config=json.load(open(f'{work_dir}/configs/PBMC_bulkATAC_{sample}_fold{fold}.JSON', 'r')),
                          group_names=[sample],
                          verbose=False,
                          launch=True,
                          return_adata=True, # turn this as True
                          overwrite_seqattr=True,
                          post_normalize=True,
                          save_key=f'PBMC_bulkATAC_{sample}', # and input a save_key
                          save_path=work_dir)
# Out:
# seq2print_attr --pt /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Bcell_0_fold0-deft-spaceship-11.pt --peaks /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/regions_test.bed --method shap_hypo --wrapper count --nth_output 0 --gpus 1 2 3 --genome hg38 --decay 0.85 --save_key PBMC_bulkATAC_Bcell_0 --overwrite  --write_numpy  --model_norm count --silent
# [[None]]
# [1, 2, 3]
# signal_window 1000 dna_len 1840
# input summits 9
# valid summits after trimming edges 9
# (9, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 9
# validating loci: 100%|██████████| 9/9 [00:00<00:00, 23534.12it/s]
# fetching coverage: 100%|██████████| 9/9 [00:00<00:00, 3769.60it/s]
# [[None]]
# [3]
# signal_window 1000 dna_len 1840
# input summits 9
# valid summits after trimming edges 9
# (9, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 9
# validating loci: 100%|██████████| 9/9 [00:00<00:00, 28749.99it/s]
# fetching coverage: 100%|██████████| 9/9 [00:00<00:00, 3926.84it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Caching sequences: 100%|██████████| 9/9 [00:00<00:00, 1445.09it/s]
# working on :   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [1]
# signal_window 1000 dna_len 1840
# input summits 9
# valid summits after trimming edges 9
# (9, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 9
# validating loci: 100%|██████████| 9/9 [00:00<00:00, 29422.24it/s]
# fetching coverage: 100%|██████████| 9/9 [00:00<00:00, 3910.17it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Caching sequences: 100%|██████████| 9/9 [00:00<00:00, 1441.62it/s]
# working on : 100%|██████████| 1/1 [00:00<00:00,  1.06it/s]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.6-9.
# hypo.count.shap_hypo_0_.0.85.6-9.npz
# working on : 100%|██████████| 1/1 [00:00<00:00,  1.07it/s]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.0-3.
# hypo.count.shap_hypo_0_.0.85.0-3.npz
# [[None]]
# [2]
# signal_window 1000 dna_len 1840
# input summits 9
# valid summits after trimming edges 9
# (9, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 9
# validating loci: 100%|██████████| 9/9 [00:00<00:00, 10147.51it/s]
# fetching coverage: 100%|██████████| 9/9 [00:00<00:00, 3440.46it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Caching sequences: 100%|██████████| 9/9 [00:00<00:00, 1258.33it/s]
# working on : 100%|██████████| 1/1 [00:00<00:00,  1.00it/s]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.3-6.
# hypo.count.shap_hypo_0_.0.85.3-6.npz
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.
# hypo.count.shap_hypo_0_.0.85.npz
# seq2print_attr --pt /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Bcell_0_fold0-deft-spaceship-11.pt --peaks /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/regions_test.bed --method shap_hypo --wrapper just_sum --nth_output 0-30 --gpus 1 2 3 --genome hg38 --decay 0.85 --save_key PBMC_bulkATAC_Bcell_0 --overwrite  --write_numpy  --model_norm footprint --silent
# [[None]]
# [1, 2, 3]
# signal_window 1000 dna_len 1840
# input summits 9
# valid summits after trimming edges 9
# (9, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 9
# validating loci: 100%|██████████| 9/9 [00:00<00:00, 27695.33it/s]
# fetching coverage: 100%|██████████| 9/9 [00:00<00:00, 3826.92it/s]
# [[None]]
# [3]
# signal_window 1000 dna_len 1840
# input summits 9
# valid summits after trimming edges 9
# (9, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 9
# validating loci: 100%|██████████| 9/9 [00:00<00:00, 31197.30it/s]
# fetching coverage: 100%|██████████| 9/9 [00:00<00:00, 3446.74it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Caching sequences: 100%|██████████| 9/9 [00:00<00:00, 1387.11it/s]
# working on :   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [2]
# signal_window 1000 dna_len 1840
# input summits 9
# valid summits after trimming edges 9
# (9, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 9
# validating loci: 100%|██████████| 9/9 [00:00<00:00, 30890.95it/s]
# fetching coverage: 100%|██████████| 9/9 [00:00<00:00, 3797.28it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Caching sequences: 100%|██████████| 9/9 [00:00<00:00, 1426.42it/s]
# working on :   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [1]
# signal_window 1000 dna_len 1840
# input summits 9
# valid summits after trimming edges 9
# (9, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 9
# validating loci: 100%|██████████| 9/9 [00:00<00:00, 26696.42it/s]
# fetching coverage: 100%|██████████| 9/9 [00:00<00:00, 3351.27it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Caching sequences: 100%|██████████| 9/9 [00:00<00:00, 1265.25it/s]
# working on : 100%|██████████| 1/1 [00:01<00:00,  1.13s/it]
# working on : 100%|██████████| 1/1 [00:01<00:00,  1.11s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.6-9.
# hypo.just_sum.shap_hypo_0-30_.0.85.6-9.npz
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.3-6.
# hypo.just_sum.shap_hypo_0-30_.0.85.3-6.npz
# working on : 100%|██████████| 1/1 [00:01<00:00,  1.11s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.0-3.
# hypo.just_sum.shap_hypo_0-30_.0.85.0-3.npz
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.
# hypo.just_sum.shap_hypo_0-30_.0.85.npz
# seq2print_tfbs --count_pt /home/mhorlbec/.cache/scprinter/TFBS_0_conv_v2.pt --foot_pt /home/mhorlbec/.cache/scprinter/TFBS_1_conv_v2.pt --seq_count /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Bcell_0_fold0-deft-spaceship-11.pt_PBMC_bulkATAC_Bcell_0/attr.count.shap_hypo_0_.0.85.npz --seq_foot /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Bcell_0_fold0-deft-spaceship-11.pt_PBMC_bulkATAC_Bcell_0/attr.just_sum.shap_hypo_0-30_.0.85.npz --genome hg38 --peaks /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/regions_test.bed --save_name /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/Bcell_0 --gpus 1 2 3 --write_numpy  --collection_name /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/PBMC_bulkATAC_Bcell_0 --read_numpy  --post_normalize
# gpu 1
#   0%|          | 0/9 [00:00<?, ?it/s]
#   0%|          | 0/9 [00:00<?, ?it/s]
# (1, 9, 800)
# obs=groups, var=regions
# seq2print_attr --pt /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Bcell_1_fold0-icy-smoke-7.pt --peaks /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/regions_test.bed --method shap_hypo --wrapper count --nth_output 0 --gpus 1 2 3 --genome hg38 --decay 0.85 --save_key PBMC_bulkATAC_Bcell_1 --overwrite  --write_numpy  --model_norm count --silent
# [[None]]
# [1, 2, 3]
# signal_window 1000 dna_len 1840
# input summits 9
# valid summits after trimming edges 9
# (9, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 9
# validating loci: 100%|██████████| 9/9 [00:00<00:00, 24166.92it/s]
# fetching coverage: 100%|██████████| 9/9 [00:00<00:00, 3801.10it/s]
# [[None]]
# [3]
# signal_window 1000 dna_len 1840
# input summits 9
# valid summits after trimming edges 9
# (9, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 9
# [[None]]
# [1]
# signal_window 1000 dna_len 1840
# input summits 9
# valid summits after trimming edges 9
# (9, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 9
# validating loci: 100%|██████████| 9/9 [00:00<00:00, 28992.88it/s]
# fetching coverage: 100%|██████████| 9/9 [00:00<00:00, 3721.65it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Caching sequences: 100%|██████████| 9/9 [00:00<00:00, 1375.93it/s]
# validating loci: 100%|██████████| 9/9 [00:00<00:00, 32099.27it/s]
# fetching coverage: 100%|██████████| 9/9 [00:00<00:00, 3974.39it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Caching sequences: 100%|██████████| 9/9 [00:00<00:00, 1446.42it/s]
# working on :   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [2]
# signal_window 1000 dna_len 1840
# input summits 9
# valid summits after trimming edges 9
# (9, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 9
# validating loci: 100%|██████████| 9/9 [00:00<00:00, 22905.79it/s]
# fetching coverage: 100%|██████████| 9/9 [00:00<00:00, 3693.98it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Caching sequences: 100%|██████████| 9/9 [00:00<00:00, 1392.48it/s]
# working on : 100%|██████████| 1/1 [00:02<00:00,  2.06s/it]
# working on : 100%|██████████| 1/1 [00:02<00:00,  2.04s/it]
# working on : 100%|██████████| 1/1 [00:01<00:00,  1.99s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.6-9.
# hypo.count.shap_hypo_0_.0.85.6-9.npz
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.0-3.
# hypo.count.shap_hypo_0_.0.85.0-3.npz
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.3-6.
# hypo.count.shap_hypo_0_.0.85.3-6.npz
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.
# hypo.count.shap_hypo_0_.0.85.npz
# seq2print_attr --pt /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Bcell_1_fold0-icy-smoke-7.pt --peaks /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/regions_test.bed --method shap_hypo --wrapper just_sum --nth_output 0-30 --gpus 1 2 3 --genome hg38 --decay 0.85 --save_key PBMC_bulkATAC_Bcell_1 --overwrite  --write_numpy  --model_norm footprint --silent
# [[None]]
# [1, 2, 3]
# signal_window 1000 dna_len 1840
# input summits 9
# valid summits after trimming edges 9
# (9, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 9
# validating loci: 100%|██████████| 9/9 [00:00<00:00, 26232.62it/s]
# fetching coverage: 100%|██████████| 9/9 [00:00<00:00, 3932.16it/s]
# [[None]]
# [2]
# signal_window 1000 dna_len 1840
# input summits 9
# valid summits after trimming edges 9
# (9, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 9
# [[None]]
# [1]
# signal_window 1000 dna_len 1840
# input summits 9
# valid summits after trimming edges 9
# (9, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 9
# validating loci: 100%|██████████| 9/9 [00:00<00:00, 32346.82it/s]
# fetching coverage: 100%|██████████| 9/9 [00:00<00:00, 3886.41it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Caching sequences: 100%|██████████| 9/9 [00:00<00:00, 1399.55it/s]
# validating loci: 100%|██████████| 9/9 [00:00<00:00, 30840.47it/s]
# fetching coverage: 100%|██████████| 9/9 [00:00<00:00, 3978.58it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Caching sequences: 100%|██████████| 9/9 [00:00<00:00, 1460.19it/s]
# working on :   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [3]
# signal_window 1000 dna_len 1840
# input summits 9
# valid summits after trimming edges 9
# (9, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 9
# validating loci: 100%|██████████| 9/9 [00:00<00:00, 24737.05it/s]
# fetching coverage: 100%|██████████| 9/9 [00:00<00:00, 3489.44it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Caching sequences: 100%|██████████| 9/9 [00:00<00:00, 1283.40it/s]
# working on : 100%|██████████| 1/1 [00:02<00:00,  2.24s/it]
# working on : 100%|██████████| 1/1 [00:02<00:00,  2.21s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.3-6.
# hypo.just_sum.shap_hypo_0-30_.0.85.3-6.npz
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.0-3.
# hypo.just_sum.shap_hypo_0-30_.0.85.0-3.npz
# working on : 100%|██████████| 1/1 [00:02<00:00,  2.19s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.6-9.
# hypo.just_sum.shap_hypo_0-30_.0.85.6-9.npz
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.
# hypo.just_sum.shap_hypo_0-30_.0.85.npz
# seq2print_tfbs --count_pt /home/mhorlbec/.cache/scprinter/TFBS_0_conv_v2.pt --foot_pt /home/mhorlbec/.cache/scprinter/TFBS_1_conv_v2.pt --seq_count /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Bcell_1_fold0-icy-smoke-7.pt_PBMC_bulkATAC_Bcell_1/attr.count.shap_hypo_0_.0.85.npz --seq_foot /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Bcell_1_fold0-icy-smoke-7.pt_PBMC_bulkATAC_Bcell_1/attr.just_sum.shap_hypo_0-30_.0.85.npz --genome hg38 --peaks /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/regions_test.bed --save_name /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/Bcell_1 --gpus 1 2 3 --write_numpy  --collection_name /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/PBMC_bulkATAC_Bcell_1 --read_numpy  --post_normalize
# gpu 1
#   0%|          | 0/9 [00:00<?, ?it/s]
#   0%|          | 0/9 [00:00<?, ?it/s]
# (1, 9, 800)
# obs=groups, var=regions
# seq2print_attr --pt /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Monocyte_0_fold0-atomic-mountain-8.pt --peaks /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/regions_test.bed --method shap_hypo --wrapper count --nth_output 0 --gpus 1 2 3 --genome hg38 --decay 0.85 --save_key PBMC_bulkATAC_Monocyte_0 --overwrite  --write_numpy  --model_norm count --silent
# [[None]]
# [1, 2, 3]
# signal_window 1000 dna_len 1840
# input summits 9
# valid summits after trimming edges 9
# (9, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 9
# validating loci: 100%|██████████| 9/9 [00:00<00:00, 27962.03it/s]
# fetching coverage: 100%|██████████| 9/9 [00:00<00:00, 3768.09it/s]
# [[None]]
# [3]
# signal_window 1000 dna_len 1840
# input summits 9
# valid summits after trimming edges 9
# (9, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 9
# [[None]]
# [1]
# signal_window 1000 dna_len 1840
# input summits 9
# valid summits after trimming edges 9
# (9, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 9
# validating loci: 100%|██████████| 9/9 [00:00<00:00, 28003.51it/s]
# fetching coverage: 100%|██████████| 9/9 [00:00<00:00, 3936.26it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Caching sequences: 100%|██████████| 9/9 [00:00<00:00, 1456.24it/s]
# validating loci: 100%|██████████| 9/9 [00:00<00:00, 32044.77it/s]
# fetching coverage: 100%|██████████| 9/9 [00:00<00:00, 3955.23it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Caching sequences: 100%|██████████| 9/9 [00:00<00:00, 1444.15it/s]
# working on :   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [2]
# signal_window 1000 dna_len 1840
# input summits 9
# valid summits after trimming edges 9
# (9, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 9
# validating loci: 100%|██████████| 9/9 [00:00<00:00, 26015.67it/s]
# fetching coverage: 100%|██████████| 9/9 [00:00<00:00, 3848.38it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Caching sequences: 100%|██████████| 9/9 [00:00<00:00, 1398.88it/s]
# working on : 100%|██████████| 1/1 [00:02<00:00,  2.00s/it]
# working on : 100%|██████████| 1/1 [00:01<00:00,  2.00s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.6-9.
# hypo.count.shap_hypo_0_.0.85.6-9.npz
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.0-3.
# hypo.count.shap_hypo_0_.0.85.0-3.npz
# working on : 100%|██████████| 1/1 [00:02<00:00,  2.05s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.3-6.
# hypo.count.shap_hypo_0_.0.85.3-6.npz
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.
# hypo.count.shap_hypo_0_.0.85.npz
# seq2print_attr --pt /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Monocyte_0_fold0-atomic-mountain-8.pt --peaks /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/regions_test.bed --method shap_hypo --wrapper just_sum --nth_output 0-30 --gpus 1 2 3 --genome hg38 --decay 0.85 --save_key PBMC_bulkATAC_Monocyte_0 --overwrite  --write_numpy  --model_norm footprint --silent
# [[None]]
# [1, 2, 3]
# signal_window 1000 dna_len 1840
# input summits 9
# valid summits after trimming edges 9
# (9, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 9
# validating loci: 100%|██████████| 9/9 [00:00<00:00, 24688.51it/s]
# fetching coverage: 100%|██████████| 9/9 [00:00<00:00, 3912.19it/s]
# [[None]]
# [3]
# signal_window 1000 dna_len 1840
# input summits 9
# valid summits after trimming edges 9
# (9, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 9
# validating loci: 100%|██████████| 9/9 [00:00<00:00, 29746.84it/s]
# fetching coverage: 100%|██████████| 9/9 [00:00<00:00, 3529.90it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Caching sequences: 100%|██████████| 9/9 [00:00<00:00, 1293.43it/s]
# working on :   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [2]
# signal_window 1000 dna_len 1840
# input summits 9
# valid summits after trimming edges 9
# (9, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 9
# validating loci: 100%|██████████| 9/9 [00:00<00:00, 31017.86it/s]
# fetching coverage: 100%|██████████| 9/9 [00:00<00:00, 3927.25it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Caching sequences: 100%|██████████| 9/9 [00:00<00:00, 1411.85it/s]
# working on :   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [1]
# signal_window 1000 dna_len 1840
# input summits 9
# valid summits after trimming edges 9
# (9, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 9
# validating loci: 100%|██████████| 9/9 [00:00<00:00, 28446.67it/s]
# fetching coverage: 100%|██████████| 9/9 [00:00<00:00, 3937.90it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Caching sequences: 100%|██████████| 9/9 [00:00<00:00, 1434.28it/s]
# working on : 100%|██████████| 1/1 [00:02<00:00,  2.16s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.6-9.
# hypo.just_sum.shap_hypo_0-30_.0.85.6-9.npz
# working on : 100%|██████████| 1/1 [00:02<00:00,  2.24s/it]
# working on : 100%|██████████| 1/1 [00:02<00:00,  2.18s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.3-6.
# hypo.just_sum.shap_hypo_0-30_.0.85.3-6.npz
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.0-3.
# hypo.just_sum.shap_hypo_0-30_.0.85.0-3.npz
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.
# hypo.just_sum.shap_hypo_0-30_.0.85.npz
# seq2print_tfbs --count_pt /home/mhorlbec/.cache/scprinter/TFBS_0_conv_v2.pt --foot_pt /home/mhorlbec/.cache/scprinter/TFBS_1_conv_v2.pt --seq_count /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Monocyte_0_fold0-atomic-mountain-8.pt_PBMC_bulkATAC_Monocyte_0/attr.count.shap_hypo_0_.0.85.npz --seq_foot /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Monocyte_0_fold0-atomic-mountain-8.pt_PBMC_bulkATAC_Monocyte_0/attr.just_sum.shap_hypo_0-30_.0.85.npz --genome hg38 --peaks /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/regions_test.bed --save_name /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/Monocyte_0 --gpus 1 2 3 --write_numpy  --collection_name /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/PBMC_bulkATAC_Monocyte_0 --read_numpy  --post_normalize
# gpu 1
#   0%|          | 0/9 [00:00<?, ?it/s]
#   0%|          | 0/9 [00:00<?, ?it/s]
# (1, 9, 800)
# obs=groups, var=regions
# seq2print_attr --pt /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Monocyte_1_fold0-misty-yogurt-12.pt --peaks /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/regions_test.bed --method shap_hypo --wrapper count --nth_output 0 --gpus 1 2 3 --genome hg38 --decay 0.85 --save_key PBMC_bulkATAC_Monocyte_1 --overwrite  --write_numpy  --model_norm count --silent
# [[None]]
# [1, 2, 3]
# signal_window 1000 dna_len 1840
# input summits 9
# valid summits after trimming edges 9
# (9, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 9
# validating loci: 100%|██████████| 9/9 [00:00<00:00, 22563.50it/s]
# fetching coverage: 100%|██████████| 9/9 [00:00<00:00, 3915.84it/s]
# [[None]]
# [1]
# signal_window 1000 dna_len 1840
# input summits 9
# valid summits after trimming edges 9
# (9, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 9
# validating loci: 100%|██████████| 9/9 [00:00<00:00, 28024.30it/s]
# fetching coverage: 100%|██████████| 9/9 [00:00<00:00, 3653.57it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Caching sequences: 100%|██████████| 9/9 [00:00<00:00, 1364.05it/s]
# working on :   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [2]
# signal_window 1000 dna_len 1840
# input summits 9
# valid summits after trimming edges 9
# (9, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 9
# validating loci: 100%|██████████| 9/9 [00:00<00:00, 27858.85it/s]
# fetching coverage: 100%|██████████| 9/9 [00:00<00:00, 3777.52it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Caching sequences: 100%|██████████| 9/9 [00:00<00:00, 1440.08it/s]
# working on :   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [3]
# signal_window 1000 dna_len 1840
# input summits 9
# valid summits after trimming edges 9
# (9, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 9
# validating loci: 100%|██████████| 9/9 [00:00<00:00, 25731.93it/s]
# fetching coverage: 100%|██████████| 9/9 [00:00<00:00, 3529.57it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Caching sequences: 100%|██████████| 9/9 [00:00<00:00, 1415.14it/s]
# working on : 100%|██████████| 1/1 [00:02<00:00,  2.06s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.0-3.
# hypo.count.shap_hypo_0_.0.85.0-3.npz
# working on : 100%|██████████| 1/1 [00:02<00:00,  2.03s/it]
# working on : 100%|██████████| 1/1 [00:01<00:00,  1.98s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.3-6.
# hypo.count.shap_hypo_0_.0.85.3-6.npz
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.6-9.
# hypo.count.shap_hypo_0_.0.85.6-9.npz
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.
# hypo.count.shap_hypo_0_.0.85.npz
# seq2print_attr --pt /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Monocyte_1_fold0-misty-yogurt-12.pt --peaks /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/regions_test.bed --method shap_hypo --wrapper just_sum --nth_output 0-30 --gpus 1 2 3 --genome hg38 --decay 0.85 --save_key PBMC_bulkATAC_Monocyte_1 --overwrite  --write_numpy  --model_norm footprint --silent
# [[None]]
# [1, 2, 3]
# signal_window 1000 dna_len 1840
# input summits 9
# valid summits after trimming edges 9
# (9, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 9
# validating loci: 100%|██████████| 9/9 [00:00<00:00, 23726.42it/s]
# fetching coverage: 100%|██████████| 9/9 [00:00<00:00, 3876.04it/s]
# [[None]]
# [2]
# signal_window 1000 dna_len 1840
# input summits 9
# valid summits after trimming edges 9
# (9, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 9
# validating loci: 100%|██████████| 9/9 [00:00<00:00, 33435.55it/s]
# fetching coverage: 100%|██████████| 9/9 [00:00<00:00, 3976.06it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Caching sequences: 100%|██████████| 9/9 [00:00<00:00, 1457.03it/s]
# working on :   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [1]
# signal_window 1000 dna_len 1840
# input summits 9
# valid summits after trimming edges 9
# (9, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 9
# [[None]]
# [3]
# signal_window 1000 dna_len 1840
# input summits 9
# valid summits after trimming edges 9
# (9, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 9
# validating loci: 100%|██████████| 9/9 [00:00<00:00, 30840.47it/s]
# fetching coverage: 100%|██████████| 9/9 [00:00<00:00, 3719.09it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Caching sequences: 100%|██████████| 9/9 [00:00<00:00, 1363.75it/s]
# validating loci: 100%|██████████| 9/9 [00:00<00:00, 31248.95it/s]
# fetching coverage: 100%|██████████| 9/9 [00:00<00:00, 3880.42it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Caching sequences: 100%|██████████| 9/9 [00:00<00:00, 1434.00it/s]
# working on : 100%|██████████| 1/1 [00:02<00:00,  2.24s/it]
# working on : 100%|██████████| 1/1 [00:02<00:00,  2.24s/it]
# working on : 100%|██████████| 1/1 [00:02<00:00,  2.20s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.3-6.
# hypo.just_sum.shap_hypo_0-30_.0.85.3-6.npz
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.0-3.
# hypo.just_sum.shap_hypo_0-30_.0.85.0-3.npz
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.6-9.
# hypo.just_sum.shap_hypo_0-30_.0.85.6-9.npz
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.
# hypo.just_sum.shap_hypo_0-30_.0.85.npz
# seq2print_tfbs --count_pt /home/mhorlbec/.cache/scprinter/TFBS_0_conv_v2.pt --foot_pt /home/mhorlbec/.cache/scprinter/TFBS_1_conv_v2.pt --seq_count /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Monocyte_1_fold0-misty-yogurt-12.pt_PBMC_bulkATAC_Monocyte_1/attr.count.shap_hypo_0_.0.85.npz --seq_foot /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Monocyte_1_fold0-misty-yogurt-12.pt_PBMC_bulkATAC_Monocyte_1/attr.just_sum.shap_hypo_0-30_.0.85.npz --genome hg38 --peaks /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/regions_test.bed --save_name /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/Monocyte_1 --gpus 1 2 3 --write_numpy  --collection_name /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/PBMC_bulkATAC_Monocyte_1 --read_numpy  --post_normalize
# gpu 1
#   0%|          | 0/9 [00:00<?, ?it/s]
#   0%|          | 0/9 [00:00<?, ?it/s]
# (1, 9, 800)
# obs=groups, var=regions
# seq2print_attr --pt /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Tcell_0_fold0-effortless-energy-8.pt --peaks /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/regions_test.bed --method shap_hypo --wrapper count --nth_output 0 --gpus 1 2 3 --genome hg38 --decay 0.85 --save_key PBMC_bulkATAC_Tcell_0 --overwrite  --write_numpy  --model_norm count --silent
# [[None]]
# [1, 2, 3]
# signal_window 1000 dna_len 1840
# input summits 9
# valid summits after trimming edges 9
# (9, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 9
# validating loci: 100%|██████████| 9/9 [00:00<00:00, 28489.61it/s]
# fetching coverage: 100%|██████████| 9/9 [00:00<00:00, 3986.56it/s]
# [[None]]
# [2]
# signal_window 1000 dna_len 1840
# input summits 9
# valid summits after trimming edges 9
# (9, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 9
# [[None]]
# [3]
# signal_window 1000 dna_len 1840
# input summits 9
# valid summits after trimming edges 9
# validating loci: 100%|██████████| 9/9 [00:00<00:00, 32374.56it/s]
# fetching coverage: 100%|██████████| 9/9 [00:00<00:00, 3921.54it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Caching sequences: 100%|██████████| 9/9 [00:00<00:00, 1459.79it/s]
# validating loci: 100%|██████████| 9/9 [00:00<00:00, 26508.94it/s]
# fetching coverage: 100%|██████████| 9/9 [00:00<00:00, 3833.53it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Caching sequences: 100%|██████████| 9/9 [00:00<00:00, 1386.85it/s]
# working on :   0%|          | 0/1 [00:00<?, ?it/s]
# (9, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 9
# working on : 100%|██████████| 1/1 [00:01<00:00,  1.99s/it]
# working on : 100%|██████████| 1/1 [00:01<00:00,  2.00s/it]
# validating loci: 100%|██████████| 9/9 [00:00<00:00, 27294.82it/s]
# fetching coverage: 100%|██████████| 9/9 [00:00<00:00, 3949.03it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Caching sequences: 100%|██████████| 9/9 [00:00<00:00, 1445.81it/s]
# working on :   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [1]
# signal_window 1000 dna_len 1840
# input summits 9
# valid summits after trimming edges 9
# (9, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 9
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.3-6.
# hypo.count.shap_hypo_0_.0.85.3-6.npz
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.6-9.
# hypo.count.shap_hypo_0_.0.85.6-9.npz
# working on : 100%|██████████| 1/1 [00:02<00:00,  2.01s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.0-3.
# hypo.count.shap_hypo_0_.0.85.0-3.npz
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.
# hypo.count.shap_hypo_0_.0.85.npz
# seq2print_attr --pt /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Tcell_0_fold0-effortless-energy-8.pt --peaks /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/regions_test.bed --method shap_hypo --wrapper just_sum --nth_output 0-30 --gpus 1 2 3 --genome hg38 --decay 0.85 --save_key PBMC_bulkATAC_Tcell_0 --overwrite  --write_numpy  --model_norm footprint --silent
# [[None]]
# [1, 2, 3]
# signal_window 1000 dna_len 1840
# input summits 9
# valid summits after trimming edges 9
# (9, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 9
# validating loci: 100%|██████████| 9/9 [00:00<00:00, 21719.64it/s]
# fetching coverage: 100%|██████████| 9/9 [00:00<00:00, 3620.98it/s]
# [[None]]
# [3]
# signal_window 1000 dna_len 1840
# input summits 9
# valid summits after trimming edges 9
# (9, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 9
# validating loci: 100%|██████████| 9/9 [00:00<00:00, 33054.94it/s]
# fetching coverage: 100%|██████████| 9/9 [00:00<00:00, 3946.96it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Caching sequences: 100%|██████████| 9/9 [00:00<00:00, 1462.00it/s]
# working on :   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [2]
# signal_window 1000 dna_len 1840
# input summits 9
# valid summits after trimming edges 9
# (9, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 9
# [[None]]
# [1]
# signal_window 1000 dna_len 1840
# input summits 9
# valid summits after trimming edges 9
# (9, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 9
# validating loci: 100%|██████████| 9/9 [00:00<00:00, 27553.82it/s]
# fetching coverage: 100%|██████████| 9/9 [00:00<00:00, 3782.82it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Caching sequences: 100%|██████████| 9/9 [00:00<00:00, 1441.45it/s]
# validating loci: 100%|██████████| 9/9 [00:00<00:00, 27573.95it/s]
# fetching coverage: 100%|██████████| 9/9 [00:00<00:00, 3926.43it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Caching sequences: 100%|██████████| 9/9 [00:00<00:00, 1445.70it/s]
# working on : 100%|██████████| 1/1 [00:02<00:00,  2.23s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.6-9.
# hypo.just_sum.shap_hypo_0-30_.0.85.6-9.npz
# working on : 100%|██████████| 1/1 [00:02<00:00,  2.25s/it]
# working on : 100%|██████████| 1/1 [00:02<00:00,  2.26s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.3-6.
# hypo.just_sum.shap_hypo_0-30_.0.85.3-6.npz
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.0-3.
# hypo.just_sum.shap_hypo_0-30_.0.85.0-3.npz
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.
# hypo.just_sum.shap_hypo_0-30_.0.85.npz
# seq2print_tfbs --count_pt /home/mhorlbec/.cache/scprinter/TFBS_0_conv_v2.pt --foot_pt /home/mhorlbec/.cache/scprinter/TFBS_1_conv_v2.pt --seq_count /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Tcell_0_fold0-effortless-energy-8.pt_PBMC_bulkATAC_Tcell_0/attr.count.shap_hypo_0_.0.85.npz --seq_foot /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Tcell_0_fold0-effortless-energy-8.pt_PBMC_bulkATAC_Tcell_0/attr.just_sum.shap_hypo_0-30_.0.85.npz --genome hg38 --peaks /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/regions_test.bed --save_name /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/Tcell_0 --gpus 1 2 3 --write_numpy  --collection_name /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/PBMC_bulkATAC_Tcell_0 --read_numpy  --post_normalize
# gpu 1
#   0%|          | 0/9 [00:00<?, ?it/s]
#   0%|          | 0/9 [00:00<?, ?it/s]
# (1, 9, 800)
# obs=groups, var=regions
# seq2print_attr --pt /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Tcell_1_fold0-gentle-blaze-10.pt --peaks /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/regions_test.bed --method shap_hypo --wrapper count --nth_output 0 --gpus 1 2 3 --genome hg38 --decay 0.85 --save_key PBMC_bulkATAC_Tcell_1 --overwrite  --write_numpy  --model_norm count --silent
# [[None]]
# [1, 2, 3]
# signal_window 1000 dna_len 1840
# input summits 9
# valid summits after trimming edges 9
# (9, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 9
# validating loci: 100%|██████████| 9/9 [00:00<00:00, 25233.11it/s]
# fetching coverage: 100%|██████████| 9/9 [00:00<00:00, 3918.69it/s]
# [[None]]
# [2]
# signal_window 1000 dna_len 1840
# input summits 9
# valid summits after trimming edges 9
# (9, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 9
# validating loci: 100%|██████████| 9/9 [00:00<00:00, 31274.84it/s]
# fetching coverage: 100%|██████████| 9/9 [00:00<00:00, 3994.58it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Caching sequences: 100%|██████████| 9/9 [00:00<00:00, 1463.36it/s]
# working on :   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [3]
# signal_window 1000 dna_len 1840
# input summits 9
# valid summits after trimming edges 9
# (9, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 9
# [[None]]
# [1]
# signal_window 1000 dna_len 1840
# input summits 9
# valid summits after trimming edges 9
# (9, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 9
# validating loci: 100%|██████████| 9/9 [00:00<00:00, 24228.97it/s]
# fetching coverage: 100%|██████████| 9/9 [00:00<00:00, 3965.62it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Caching sequences: 100%|██████████| 9/9 [00:00<00:00, 1451.71it/s]
# validating loci: 100%|██████████| 9/9 [00:00<00:00, 28045.12it/s]
# fetching coverage: 100%|██████████| 9/9 [00:00<00:00, 3521.67it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Caching sequences: 100%|██████████| 9/9 [00:00<00:00, 1286.90it/s]
# working on : 100%|██████████| 1/1 [00:02<00:00,  2.00s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.3-6.
# hypo.count.shap_hypo_0_.0.85.3-6.npz
# working on : 100%|██████████| 1/1 [00:02<00:00,  2.01s/it]
# working on : 100%|██████████| 1/1 [00:02<00:00,  2.04s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.6-9.
# hypo.count.shap_hypo_0_.0.85.6-9.npz
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.0-3.
# hypo.count.shap_hypo_0_.0.85.0-3.npz
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.
# hypo.count.shap_hypo_0_.0.85.npz
# seq2print_attr --pt /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Tcell_1_fold0-gentle-blaze-10.pt --peaks /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/regions_test.bed --method shap_hypo --wrapper just_sum --nth_output 0-30 --gpus 1 2 3 --genome hg38 --decay 0.85 --save_key PBMC_bulkATAC_Tcell_1 --overwrite  --write_numpy  --model_norm footprint --silent
# [[None]]
# [1, 2, 3]
# signal_window 1000 dna_len 1840
# input summits 9
# valid summits after trimming edges 9
# (9, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 9
# validating loci: 100%|██████████| 9/9 [00:00<00:00, 25317.73it/s]
# fetching coverage: 100%|██████████| 9/9 [00:00<00:00, 3917.06it/s]
# [[None]]
# [1]
# signal_window 1000 dna_len 1840
# input summits 9
# valid summits after trimming edges 9
# (9, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 9
# validating loci: 100%|██████████| 9/9 [00:00<00:00, 23711.52it/s]
# fetching coverage: 100%|██████████| 9/9 [00:00<00:00, 3743.43it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Caching sequences: 100%|██████████| 9/9 [00:00<00:00, 1431.07it/s]
# working on :   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [2]
# signal_window 1000 dna_len 1840
# input summits 9
# valid summits after trimming edges 9
# (9, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 9
# [[None]]
# [3]
# signal_window 1000 dna_len 1840
# input summits 9
# valid summits after trimming edges 9
# (9, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 9
# validating loci: 100%|██████████| 9/9 [00:00<00:00, 26715.31it/s]
# fetching coverage: 100%|██████████| 9/9 [00:00<00:00, 3913.41it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Caching sequences: 100%|██████████| 9/9 [00:00<00:00, 1431.77it/s]
# validating loci: 100%|██████████| 9/9 [00:00<00:00, 26453.21it/s]
# fetching coverage: 100%|██████████| 9/9 [00:00<00:00, 3801.10it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Caching sequences: 100%|██████████| 9/9 [00:00<00:00, 1450.42it/s]
# working on : 100%|██████████| 1/1 [00:02<00:00,  2.19s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.0-3.
# hypo.just_sum.shap_hypo_0-30_.0.85.0-3.npz
# working on : 100%|██████████| 1/1 [00:02<00:00,  2.22s/it]
# working on : 100%|██████████| 1/1 [00:02<00:00,  2.29s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.6-9.
# hypo.just_sum.shap_hypo_0-30_.0.85.6-9.npz
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.3-6.
# hypo.just_sum.shap_hypo_0-30_.0.85.3-6.npz
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.
# hypo.just_sum.shap_hypo_0-30_.0.85.npz
# seq2print_tfbs --count_pt /home/mhorlbec/.cache/scprinter/TFBS_0_conv_v2.pt --foot_pt /home/mhorlbec/.cache/scprinter/TFBS_1_conv_v2.pt --seq_count /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Tcell_1_fold0-gentle-blaze-10.pt_PBMC_bulkATAC_Tcell_1/attr.count.shap_hypo_0_.0.85.npz --seq_foot /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Tcell_1_fold0-gentle-blaze-10.pt_PBMC_bulkATAC_Tcell_1/attr.just_sum.shap_hypo_0-30_.0.85.npz --genome hg38 --peaks /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/regions_test.bed --save_name /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/Tcell_1 --gpus 1 2 3 --write_numpy  --collection_name /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/PBMC_bulkATAC_Tcell_1 --read_numpy  --post_normalize
# gpu 1
#   0%|          | 0/9 [00:00<?, ?it/s]
#   0%|          | 0/9 [00:00<?, ?it/s]
# (1, 9, 800)
# obs=groups, var=regions

# %% [markdown]
# Below you can see that seq2PRINT can predict cell-type-specific TF binding consistent with known biology

# %%
if not os.path.exists(f'{work_dir}/plots'):
    os.system(f'mkdir {work_dir}/plots')
for region in regions_dict.keys():
    print(region, regions_dict[region])
    tfbs = pd.DataFrame(np.array([adata_tfbs[sample].obsm[region] for sample in samples]).squeeze(), index=samples)
    sns.heatmap(tfbs, cmap='RdBu_r')
    plt.savefig(f'{work_dir}/plots/TFBS_{region}.png')
    plt.show()
# Out:
# chr11:47378230-47379030 SPI1
# chr5:140633035-140633835 CD14
# chr19:41876833-41877633 CD79a
# chr11:118342294-118343094 CD3D
# chr17:58281312-58282112 MPO
# chr16:31259594-31260394 ITGAM
# chr3:39281281-39282081 CX3CR1
# chr9:37033951-37034751 PAX5

# %% [markdown]
# ### Compute TF binding scores on a larger number of peaks

# %% [markdown]
# When we run TF binding score calculation on a large number of peaks, we set return_adata=False and instead save the results only to bigwig files.

# %% [markdown]
# We first filter peaks by depth so we remove low coverage peaks and also reduce the computational load

# %%
# First construct a peak-by-cell matrix of ATAC counts
peak_path = f'{work_dir}/regions.bed'
adata = scp.pp.make_peak_matrix(printer,
                       regions=peak_path,
                       region_width=300,
                       cell_grouping=None,
                       group_names=None,
                       sparse=True)
adata.write(f'{work_dir}/cell_peak.h5ad')
# Out:
# Making peak matrix:   0%|          | 0/296069 [00:00<?, ?it/s]

# %%
# Remove regions with low coverage (helps to reduce total peak number and save time. The full list of 300k peaks contains many very weak peaks)
regions = pd.read_csv(f'{work_dir}/regions.bed', sep='\t', header=None)
adata = anndata.read_h5ad(f'{work_dir}/cell_peak.h5ad')
peak_depth = np.array(np.sum(adata.X, axis=0)).squeeze()
regions_filt = regions.iloc[np.where(peak_depth > 200)[0], :]
regions_filt.to_csv(f'{work_dir}/regions_filt.bed', 
                     sep='\t', header=False, index=False)

# %% [markdown]
# Now compute TF binding scores on the filtered list of peaks, remember to change the ```gpus``` parameter to use the GPUs available to you.

# %%
import json
for sample_ind, sample in enumerate(samples):
    scp.tl.seq_tfbs_seq2print(seq_attr_count=None,
                          seq_attr_footprint=None,
                          genome=printer.genome,
                          region_path=f'{work_dir}/regions_filt.bed',
                          gpus=[6,7],
                          model_type='seq2print',
                          model_path=model_path_dict[sample], # For now we just run on one fold
                          lora_config=json.load(open(f'{work_dir}/configs/PBMC_bulkATAC_{sample}_fold{fold}.JSON', 'r')),
                          group_names=[sample],
                          verbose=False,
                          launch=True,
                          return_adata=False, 
                          overwrite_seqattr=True,
                          post_normalize=True,
                          save_key=f'PBMC_bulkATAC_{sample}', # and input a save_key
                          save_path=work_dir)
# Out:
# seq2print_attr --pt /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Bcell_0_fold0-deft-spaceship-11.pt --peaks /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/regions_filt.bed --method shap_hypo --wrapper count --nth_output 0 --gpus 6 7 --genome hg38 --decay 0.85 --save_key PBMC_bulkATAC_Bcell_0 --overwrite  --model_norm count --silent
# [[None]]
# [6, 7]
# signal_window 1000 dna_len 1840
# input summits 55094
# valid summits after trimming edges 55094
# validating loci: 100%|██████████| 55094/55094 [00:00<00:00, 2709959.83it/s]
# fetching coverage: 100%|██████████| 55094/55094 [00:10<00:00, 5330.63it/s]
# (55094, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 55094
# [[None]]
# [7]
# signal_window 1000 dna_len 1840
# input summits 55094
# valid summits after trimming edges 55094
# [[None]]
# [6]
# signal_window 1000 dna_len 1840
# input summits 55094
# valid summits after trimming edges 55094
# validating loci: 100%|██████████| 55094/55094 [00:00<00:00, 2714384.54it/s]
# validating loci: 100%|██████████| 55094/55094 [00:00<00:00, 2592163.24it/s]
# fetching coverage: 100%|██████████| 55094/55094 [00:10<00:00, 5373.99it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Caching sequences:   0%|          | 0/55094 [00:00<?, ?it/s]
# (55094, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 55094
# (55094, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 55094
# fetching coverage:  99%|█████████▊| 54391/55094 [00:10<00:00, 5220.92it/s]
# fetching coverage: 100%|██████████| 55094/55094 [00:10<00:00, 5335.83it/s]A
#   0%|          | 0/1 [00:00<?, ?it/s]
# Caching sequences:   0%|          | 0/55094 [00:00<?, ?it/s]
# Caching sequences:   1%|          | 356/55094 [00:00<00:30, 1779.25it/s]
# Caching sequences:   0%|          | 177/55094 [00:00<00:31, 1760.58it/s]
# Caching sequences:   1%|          | 535/55094 [00:00<00:30, 1780.47it/s]
# Caching sequences:   1%|          | 354/55094 [00:00<00:31, 1760.55it/s]
# Caching sequences:   1%|▏         | 714/55094 [00:00<00:31, 1746.06it/s]
# Caching sequences:   1%|          | 531/55094 [00:00<00:31, 1759.78it/s]
# Caching sequences:   2%|▏         | 889/55094 [00:00<00:31, 1722.95it/s]
# Caching sequences:   1%|▏         | 707/55094 [00:00<00:31, 1735.92it/s]
# Caching sequences:   2%|▏         | 1062/55094 [00:00<00:31, 1717.75it/s]
# Caching sequences:   2%|▏         | 881/55094 [00:00<00:31, 1719.74it/s]
# Caching sequences:   2%|▏         | 1241/55094 [00:00<00:30, 1740.32it/s]
# Caching sequences:   2%|▏         | 1054/55094 [00:00<00:31, 1718.92it/s]
# Caching sequences:   3%|▎         | 1417/55094 [00:00<00:30, 1744.54it/s]
# Caching sequences:   2%|▏         | 1233/55094 [00:00<00:31, 1737.25it/s]
# Caching sequences:   3%|▎         | 1592/55094 [00:00<00:30, 1743.60it/s]
# Caching sequences:   3%|▎         | 1407/55094 [00:00<00:30, 1735.58it/s]
# Caching sequences:   3%|▎         | 1772/55094 [00:01<00:30, 1759.44it/s]
# Caching sequences:   3%|▎         | 1582/55094 [00:00<00:30, 1738.71it/s]
# Caching sequences:   4%|▎         | 1948/55094 [00:01<00:30, 1753.75it/s]
# Caching sequences:   3%|▎         | 1763/55094 [00:01<00:30, 1758.78it/s]
# Caching sequences:   4%|▍         | 2126/55094 [00:01<00:30, 1761.05it/s]
# Caching sequences:   4%|▎         | 1939/55094 [00:01<00:30, 1747.87it/s]
# Caching sequences:   4%|▍         | 2303/55094 [00:01<00:30, 1756.79it/s]
# Caching sequences:   4%|▍         | 2114/55094 [00:01<00:30, 1744.48it/s]
# Caching sequences:   4%|▍         | 2479/55094 [00:01<00:30, 1737.04it/s]
# Caching sequences:   4%|▍         | 2290/55094 [00:01<00:30, 1747.77it/s]
# Caching sequences:   5%|▍         | 2654/55094 [00:01<00:30, 1739.62it/s]
# Caching sequences:   4%|▍         | 2465/55094 [00:01<00:30, 1736.48it/s]
# Caching sequences:   5%|▌         | 2831/55094 [00:01<00:29, 1746.67it/s]
# Caching sequences:   5%|▍         | 2639/55094 [00:01<00:30, 1736.03it/s]
# Caching sequences:   5%|▌         | 3006/55094 [00:01<00:29, 1738.52it/s]
# Caching sequences:   5%|▌         | 2817/55094 [00:01<00:29, 1747.71it/s]
# Caching sequences:   6%|▌         | 3181/55094 [00:01<00:29, 1740.34it/s]
# Caching sequences:   5%|▌         | 2992/55094 [00:01<00:30, 1730.71it/s]
# Caching sequences:   6%|▌         | 3356/55094 [00:01<00:30, 1719.79it/s]
# Caching sequences:   6%|▌         | 3166/55094 [00:01<00:30, 1702.75it/s]
# Caching sequences:   6%|▋         | 3529/55094 [00:02<00:30, 1710.00it/s]
# Caching sequences:   6%|▌         | 3338/55094 [00:01<00:30, 1706.20it/s]
# Caching sequences:   7%|▋         | 3709/55094 [00:02<00:29, 1734.05it/s]
# Caching sequences:   6%|▋         | 3512/55094 [00:02<00:30, 1714.23it/s]
# Caching sequences:   7%|▋         | 3888/55094 [00:02<00:29, 1748.69it/s]
# Caching sequences:   7%|▋         | 3690/55094 [00:02<00:29, 1732.48it/s]
# Caching sequences:   7%|▋         | 4063/55094 [00:02<00:29, 1746.90it/s]
# Caching sequences:   7%|▋         | 3868/55094 [00:02<00:29, 1744.94it/s]
# Caching sequences:   8%|▊         | 4238/55094 [00:02<00:29, 1738.89it/s]
# Caching sequences:   7%|▋         | 4043/55094 [00:02<00:29, 1745.70it/s]
# Caching sequences:   8%|▊         | 4412/55094 [00:02<00:29, 1725.20it/s]
# Caching sequences:   8%|▊         | 4218/55094 [00:02<00:29, 1737.99it/s]
# Caching sequences:   8%|▊         | 4589/55094 [00:02<00:29, 1736.90it/s]
# Caching sequences:   8%|▊         | 4392/55094 [00:02<00:29, 1719.34it/s]
# Caching sequences:   9%|▊         | 4763/55094 [00:02<00:29, 1728.00it/s]
# Caching sequences:   8%|▊         | 4568/55094 [00:02<00:29, 1728.56it/s]
# Caching sequences:   9%|▉         | 4941/55094 [00:02<00:28, 1742.51it/s]
# Caching sequences:   9%|▊         | 4745/55094 [00:02<00:28, 1738.93it/s]
# Caching sequences:   9%|▉         | 5116/55094 [00:02<00:28, 1738.72it/s]
# Caching sequences:   9%|▉         | 4921/55094 [00:02<00:28, 1744.60it/s]
# Caching sequences:  10%|▉         | 5291/55094 [00:03<00:28, 1741.00it/s]
# Caching sequences:   9%|▉         | 5096/55094 [00:02<00:28, 1735.40it/s]
# Caching sequences:  10%|▉         | 5466/55094 [00:03<00:28, 1742.33it/s]
# Caching sequences:  10%|▉         | 5270/55094 [00:03<00:28, 1733.38it/s]
# Caching sequences:  10%|█         | 5643/55094 [00:03<00:28, 1749.05it/s]
# Caching sequences:  10%|▉         | 5444/55094 [00:03<00:28, 1732.91it/s]
# Caching sequences:  11%|█         | 5820/55094 [00:03<00:28, 1752.02it/s]
# Caching sequences:  10%|█         | 5622/55094 [00:03<00:28, 1746.62it/s]
# Caching sequences:  11%|█         | 5997/55094 [00:03<00:27, 1754.92it/s]
# Caching sequences:  11%|█         | 5797/55094 [00:03<00:28, 1744.34it/s]
# Caching sequences:  11%|█         | 6173/55094 [00:03<00:28, 1739.22it/s]
# Caching sequences:  11%|█         | 5972/55094 [00:03<00:28, 1745.16it/s]
# Caching sequences:  12%|█▏        | 6348/55094 [00:03<00:28, 1740.73it/s]
# Caching sequences:  11%|█         | 6147/55094 [00:03<00:28, 1740.04it/s]
# Caching sequences:  12%|█▏        | 6523/55094 [00:03<00:27, 1738.48it/s]
# Caching sequences:  11%|█▏        | 6322/55094 [00:03<00:28, 1729.13it/s]
# Caching sequences:  12%|█▏        | 6697/55094 [00:03<00:27, 1731.64it/s]
# Caching sequences:  12%|█▏        | 6498/55094 [00:03<00:27, 1737.55it/s]
# Caching sequences:  12%|█▏        | 6874/55094 [00:03<00:27, 1740.24it/s]
# Caching sequences:  12%|█▏        | 6672/55094 [00:03<00:28, 1721.00it/s]
# Caching sequences:  13%|█▎        | 7054/55094 [00:04<00:27, 1756.67it/s]
# Caching sequences:  12%|█▏        | 6849/55094 [00:03<00:27, 1731.84it/s]
# Caching sequences:  13%|█▎        | 7232/55094 [00:04<00:27, 1761.23it/s]
# Caching sequences:  13%|█▎        | 7028/55094 [00:04<00:27, 1747.73it/s]
# Caching sequences:  13%|█▎        | 7412/55094 [00:04<00:26, 1772.46it/s]
# Caching sequences:  13%|█▎        | 7204/55094 [00:04<00:27, 1749.49it/s]
# Caching sequences:  31%|███       | 17197/55094 [00:09<00:21, 1722.85it/s]
# Caching sequences:  30%|███       | 16772/55094 [00:09<00:22, 1672.44it/s]
# Caching sequences:  32%|███▏      | 17371/55094 [00:10<00:21, 1725.20it/s]
# Caching sequences:  31%|███       | 16940/55094 [00:09<00:22, 1664.33it/s]
# Caching sequences:  32%|███▏      | 17548/55094 [00:10<00:21, 1734.52it/s]
# Caching sequences:  31%|███       | 17116/55094 [00:09<00:22, 1691.63it/s]
# Caching sequences:  32%|███▏      | 17722/55094 [00:10<00:21, 1730.71it/s]
# Caching sequences:  31%|███▏      | 17286/55094 [00:10<00:22, 1687.65it/s]
# Caching sequences:  32%|███▏      | 17896/55094 [00:10<00:21, 1720.15it/s]
# Caching sequences:  32%|███▏      | 17457/55094 [00:10<00:22, 1694.00it/s]
# Caching sequences:  33%|███▎      | 18069/55094 [00:10<00:21, 1718.69it/s]
# Caching sequences:  32%|███▏      | 17631/55094 [00:10<00:21, 1704.29it/s]
# Caching sequences:  33%|███▎      | 18241/55094 [00:10<00:21, 1712.11it/s]
# Caching sequences:  32%|███▏      | 17802/55094 [00:10<00:21, 1697.64it/s]
# Caching sequences:  33%|███▎      | 18420/55094 [00:10<00:21, 1734.05it/s]
# Caching sequences:  33%|███▎      | 17975/55094 [00:10<00:21, 1705.80it/s]
# Caching sequences:  34%|███▎      | 18594/55094 [00:10<00:21, 1719.71it/s]
# Caching sequences:  33%|███▎      | 18146/55094 [00:10<00:21, 1684.60it/s]
# Caching sequences:  34%|███▍      | 18767/55094 [00:10<00:21, 1705.69it/s]
# Caching sequences:  33%|███▎      | 18318/55094 [00:10<00:21, 1695.04it/s]
# Caching sequences:  34%|███▍      | 18943/55094 [00:10<00:20, 1721.48it/s]
# Caching sequences:  34%|███▎      | 18495/55094 [00:10<00:21, 1715.52it/s]
# Caching sequences:  34%|███▍      | 18667/55094 [00:10<00:21, 1713.84it/s]
# Caching sequences:  35%|███▍      | 19116/55094 [00:11<00:20, 1716.31it/s]
#
# Caching sequences:  35%|███▌      | 19290/55094 [00:11<00:20, 1722.30it/s]
# Caching sequences:  35%|███▍      | 19012/55094 [00:11<00:20, 1718.33it/s]
# Caching sequences:  35%|███▌      | 19463/55094 [00:11<00:20, 1718.94it/s]
# Caching sequences:  35%|███▍      | 19186/55094 [00:11<00:20, 1724.08it/s]
# Caching sequences:  36%|███▌      | 19638/55094 [00:11<00:20, 1727.44it/s]
# Caching sequences:  35%|███▌      | 19359/55094 [00:11<00:20, 1720.16it/s]
# Caching sequences:  36%|███▌      | 19811/55094 [00:11<00:20, 1716.06it/s]
# Caching sequences:  35%|███▌      | 19532/55094 [00:11<00:20, 1715.72it/s]
# Caching sequences:  36%|███▋      | 19985/55094 [00:11<00:20, 1721.97it/s]
# Caching sequences:  36%|███▌      | 19705/55094 [00:11<00:20, 1718.35it/s]
# Caching sequences:  37%|███▋      | 20158/55094 [00:11<00:20, 1723.27it/s]
# Caching sequences:  37%|███▋      | 20333/55094 [00:11<00:20, 1729.28it/s]
# Caching sequences:  36%|███▌      | 19877/55094 [00:11<00:20, 1708.39it/s]
# Caching sequences:  81%|████████▏ | 44851/55094 [00:26<00:05, 1719.67it/s]
# Caching sequences:  83%|████████▎ | 45568/55094 [00:26<00:05, 1707.80it/s]
# Caching sequences:  82%|████████▏ | 45023/55094 [00:26<00:05, 1711.68it/s]
# Caching sequences:  83%|████████▎ | 45739/55094 [00:26<00:05, 1701.12it/s]
# Caching sequences:  82%|████████▏ | 45195/55094 [00:26<00:05, 1713.85it/s]
# Caching sequences:  83%|████████▎ | 45914/55094 [00:26<00:05, 1713.77it/s]
# Caching sequences:  82%|████████▏ | 45371/55094 [00:26<00:05, 1725.52it/s]
# Caching sequences:  84%|████████▎ | 46086/55094 [00:27<00:05, 1702.93it/s]
# Caching sequences:  83%|████████▎ | 45544/55094 [00:26<00:05, 1710.84it/s]
# Caching sequences:  84%|████████▍ | 46260/55094 [00:27<00:05, 1712.38it/s]
# Caching sequences:  83%|████████▎ | 45716/55094 [00:26<00:05, 1711.18it/s]
# Caching sequences:  84%|████████▍ | 46432/55094 [00:27<00:05, 1692.52it/s]
# Caching sequences:  83%|████████▎ | 45888/55094 [00:27<00:05, 1686.38it/s]
# Caching sequences:  85%|████████▍ | 46602/55094 [00:27<00:05, 1668.35it/s]
# Caching sequences:  84%|████████▎ | 46059/55094 [00:27<00:05, 1692.03it/s]
# Caching sequences:  85%|████████▍ | 46769/55094 [00:27<00:04, 1666.05it/s]
# Caching sequences:  84%|████████▍ | 46231/55094 [00:27<00:05, 1699.86it/s]
# Caching sequences:  85%|████████▌ | 46943/55094 [00:27<00:04, 1684.90it/s]
# Caching sequences:  84%|████████▍ | 46402/55094 [00:27<00:05, 1691.46it/s]
# Caching sequences:  86%|████████▌ | 47118/55094 [00:27<00:04, 1703.99it/s]
# Caching sequences:  85%|████████▍ | 46572/55094 [00:27<00:05, 1687.55it/s]
# Caching sequences:  86%|████████▌ | 47296/55094 [00:27<00:04, 1724.57it/s]
# Caching sequences:  85%|████████▍ | 46742/55094 [00:27<00:04, 1687.10it/s]
# Caching sequences:  86%|████████▌ | 47471/55094 [00:27<00:04, 1730.02it/s]
# Caching sequences:  85%|████████▌ | 46911/55094 [00:27<00:04, 1686.44it/s]
# Caching sequences:  86%|████████▋ | 47645/55094 [00:27<00:04, 1723.89it/s]
# Caching sequences:  85%|████████▌ | 47087/55094 [00:27<00:04, 1707.20it/s]
# Caching sequences:  87%|████████▋ | 47818/55094 [00:28<00:04, 1695.81it/s]
# Caching sequences:  86%|████████▌ | 47263/55094 [00:27<00:04, 1722.41it/s]
# Caching sequences:  87%|████████▋ | 47991/55094 [00:28<00:04, 1704.99it/s]
# Caching sequences:  86%|████████▌ | 47438/55094 [00:27<00:04, 1728.16it/s]
# Caching sequences:  87%|████████▋ | 48162/55094 [00:28<00:04, 1698.09it/s]
# Caching sequences:  86%|████████▋ | 47611/55094 [00:28<00:04, 1720.91it/s]
# Caching sequences:  88%|████████▊ | 48332/55094 [00:28<00:03, 1694.19it/s]
# Caching sequences:  87%|████████▋ | 47784/55094 [00:28<00:04, 1704.88it/s]
# Caching sequences:  88%|████████▊ | 48503/55094 [00:28<00:03, 1697.27it/s]
# Caching sequences:  87%|████████▋ | 47955/55094 [00:28<00:04, 1705.51it/s]
# Caching sequences:  88%|████████▊ | 48674/55094 [00:28<00:03, 1699.08it/s]
# Caching sequences:  87%|████████▋ | 48126/55094 [00:28<00:04, 1701.33it/s]
# Caching sequences:  89%|████████▊ | 48844/55094 [00:28<00:03, 1689.35it/s]
# Caching sequences:  88%|████████▊ | 48298/55094 [00:28<00:03, 1704.55it/s]
# Caching sequences:  89%|████████▉ | 49016/55094 [00:28<00:03, 1696.52it/s]
# Caching sequences:  88%|████████▊ | 48469/55094 [00:28<00:03, 1689.23it/s]
# Caching sequences:  89%|████████▉ | 49186/55094 [00:28<00:03, 1682.00it/s]
# Caching sequences:  88%|████████▊ | 48638/55094 [00:28<00:03, 1688.10it/s]
# Caching sequences:  90%|████████▉ | 49358/55094 [00:28<00:03, 1690.62it/s]
# Caching sequences:  89%|████████▊ | 48809/55094 [00:28<00:03, 1693.37it/s]
# Caching sequences:  90%|████████▉ | 49529/55094 [00:29<00:03, 1695.50it/s]
# Caching sequences:  89%|████████▉ | 48979/55094 [00:28<00:03, 1694.88it/s]
# Caching sequences:  90%|█████████ | 49705/55094 [00:29<00:03, 1712.96it/s]
# Caching sequences:  89%|████████▉ | 49149/55094 [00:28<00:03, 1691.99it/s]
# Caching sequences:  91%|█████████ | 49887/55094 [00:29<00:02, 1743.25it/s]
# Caching sequences:  90%|████████▉ | 49319/55094 [00:29<00:03, 1694.13it/s]
# Caching sequences:  91%|█████████ | 50062/55094 [00:29<00:02, 1702.68it/s]
# Caching sequences:  90%|████████▉ | 49489/55094 [00:29<00:03, 1662.47it/s]
# Caching sequences:  91%|█████████ | 50233/55094 [00:29<00:02, 1701.86it/s]
# Caching sequences:  90%|█████████ | 49663/55094 [00:29<00:03, 1683.65it/s]
# Caching sequences:  91%|█████████▏| 50405/55094 [00:29<00:02, 1705.53it/s]
# Caching sequences:  90%|█████████ | 49841/55094 [00:29<00:03, 1710.28it/s]
# Caching sequences:  92%|█████████▏| 50584/55094 [00:29<00:02, 1729.13it/s]
# Caching sequences:  91%|█████████ | 50015/55094 [00:29<00:02, 1717.83it/s]
# Caching sequences:  92%|█████████▏| 50758/55094 [00:29<00:02, 1729.66it/s]
# Caching sequences:  91%|█████████ | 50187/55094 [00:29<00:02, 1715.34it/s]
# Caching sequences:  92%|█████████▏| 50932/55094 [00:29<00:02, 1714.26it/s]
# Caching sequences:  91%|█████████▏| 50360/55094 [00:29<00:02, 1717.27it/s]
# Caching sequences:  93%|█████████▎| 51104/55094 [00:29<00:02, 1710.59it/s]
# Caching sequences:  92%|█████████▏| 50535/55094 [00:29<00:02, 1725.06it/s]
# Caching sequences:  93%|█████████▎| 51276/55094 [00:30<00:02, 1696.62it/s]
# Caching sequences:  92%|█████████▏| 50710/55094 [00:29<00:02, 1730.33it/s]
# Caching sequences:  93%|█████████▎| 51449/55094 [00:30<00:02, 1704.62it/s]
# Caching sequences:  92%|█████████▏| 50884/55094 [00:29<00:02, 1723.29it/s]
# Caching sequences:  94%|█████████▎| 51623/55094 [00:30<00:02, 1713.93it/s]
# Caching sequences:  93%|█████████▎| 51057/55094 [00:30<00:02, 1711.31it/s]
# Caching sequences:  94%|█████████▍| 51795/55094 [00:30<00:01, 1699.36it/s]
# Caching sequences:  93%|█████████▎| 51229/55094 [00:30<00:02, 1692.90it/s]
# Caching sequences:  94%|█████████▍| 51969/55094 [00:30<00:01, 1710.19it/s]
# Caching sequences:  93%|█████████▎| 51399/55094 [00:30<00:02, 1693.23it/s]
# Caching sequences:  95%|█████████▍| 52144/55094 [00:30<00:01, 1720.34it/s]
# Caching sequences:  94%|█████████▎| 51573/55094 [00:30<00:02, 1705.00it/s]
# Caching sequences:  95%|█████████▍| 52317/55094 [00:30<00:01, 1716.94it/s]
# Caching sequences:  94%|█████████▍| 51744/55094 [00:30<00:01, 1696.06it/s]
# Caching sequences:  95%|█████████▌| 52491/55094 [00:30<00:01, 1722.67it/s]
# Caching sequences:  94%|█████████▍| 51920/55094 [00:30<00:01, 1714.06it/s]
# Caching sequences:  96%|█████████▌| 52664/55094 [00:30<00:01, 1714.13it/s]
# Caching sequences:  95%|█████████▍| 52092/55094 [00:30<00:01, 1705.05it/s]
# Caching sequences:  96%|█████████▌| 52836/55094 [00:30<00:01, 1711.89it/s]
# Caching sequences:  95%|█████████▍| 52265/55094 [00:30<00:01, 1710.52it/s]
# Caching sequences:  96%|█████████▌| 53008/55094 [00:31<00:01, 1712.71it/s]
# Caching sequences:  95%|█████████▌| 52437/55094 [00:30<00:01, 1710.99it/s]
# Caching sequences:  97%|█████████▋| 53180/55094 [00:31<00:01, 1707.44it/s]
# Caching sequences:  95%|█████████▌| 52609/55094 [00:31<00:01, 1710.88it/s]
# Caching sequences:  97%|█████████▋| 53353/55094 [00:31<00:01, 1711.01it/s]
# Caching sequences:  96%|█████████▌| 52781/55094 [00:31<00:01, 1707.94it/s]
# Caching sequences:  97%|█████████▋| 53525/55094 [00:31<00:00, 1709.66it/s]
# Caching sequences:  96%|█████████▌| 52955/55094 [00:31<00:01, 1714.16it/s]
# Caching sequences:  97%|█████████▋| 53696/55094 [00:31<00:00, 1709.23it/s]
# Caching sequences:  96%|█████████▋| 53127/55094 [00:31<00:01, 1708.01it/s]
# Caching sequences:  98%|█████████▊| 53867/55094 [00:31<00:00, 1701.21it/s]
# Caching sequences:  97%|█████████▋| 53298/55094 [00:31<00:01, 1707.24it/s]
# Caching sequences:  98%|█████████▊| 54038/55094 [00:31<00:00, 1682.20it/s]
# Caching sequences:  97%|█████████▋| 53469/55094 [00:31<00:00, 1695.33it/s]
# Caching sequences:  98%|█████████▊| 54211/55094 [00:31<00:00, 1694.06it/s]
# Caching sequences:  97%|█████████▋| 53641/55094 [00:31<00:00, 1700.40it/s]
# ...
# Caching sequences:  14%|█▍        | 7987/55094 [00:04<00:26, 1772.35it/s]
# Caching sequences:  16%|█▌        | 8924/55094 [00:05<00:26, 1771.64it/s]
# Caching sequences:  15%|█▍        | 8165/55094 [00:04<00:26, 1749.78it/s]
# Caching sequences:  17%|█▋        | 9104/55094 [00:05<00:25, 1779.04it/s]
# Caching sequences:  34%|███▍      | 18856/55094 [00:10<00:20, 1751.80it/s]
# Caching sequences:  33%|███▎      | 18062/55094 [00:10<00:21, 1732.56it/s]
# Caching sequences:  35%|███▍      | 19032/55094 [00:10<00:20, 1749.40it/s]
# Caching sequences:  33%|███▎      | 18236/55094 [00:10<00:21, 1733.67it/s]
# Caching sequences:  35%|███▍      | 19208/55094 [00:10<00:20, 1750.20it/s]
# Caching sequences:  33%|███▎      | 18416/55094 [00:10<00:20, 1752.81it/s]
# Caching sequences:  35%|███▌      | 19384/55094 [00:11<00:20, 1738.89it/s]
# Caching sequences:  34%|███▎      | 18592/55094 [00:10<00:20, 1752.52it/s]
# Caching sequences:  36%|███▌      | 19559/55094 [00:11<00:20, 1740.77it/s]
# Caching sequences:  34%|███▍      | 18768/55094 [00:10<00:20, 1737.03it/s]
# Caching sequences:  36%|███▌      | 19734/55094 [00:11<00:20, 1740.99it/s]
# Caching sequences:  34%|███▍      | 18944/55094 [00:10<00:20, 1743.30it/s]
# Caching sequences:  36%|███▌      | 19909/55094 [00:11<00:20, 1734.58it/s]
# Caching sequences:  35%|███▍      | 19119/55094 [00:10<00:20, 1733.94it/s]
# Caching sequences:  36%|███▋      | 20086/55094 [00:11<00:20, 1742.08it/s]
# Caching sequences:  35%|███▌      | 19295/55094 [00:11<00:20, 1740.47it/s]
# Caching sequences:  37%|███▋      | 20262/55094 [00:11<00:19, 1746.34it/s]
# Caching sequences:  35%|███▌      | 19470/55094 [00:11<00:20, 1729.65it/s]
# Caching sequences:  37%|███▋      | 20439/55094 [00:11<00:19, 1752.12it/s]
# Caching sequences:  36%|███▌      | 19647/55094 [00:11<00:20, 1740.10it/s]
# Caching sequences:  37%|███▋      | 20615/55094 [00:11<00:19, 1744.43it/s]
# Caching sequences:  36%|███▌      | 19822/55094 [00:11<00:20, 1721.76it/s]
# Caching sequences:  38%|███▊      | 20791/55094 [00:11<00:19, 1748.37it/s]
# Caching sequences:  36%|███▋      | 19999/55094 [00:11<00:20, 1735.11it/s]
# Caching sequences:  38%|███▊      | 20966/55094 [00:11<00:19, 1745.00it/s]
# Caching sequences:  37%|███▋      | 20173/55094 [00:11<00:20, 1733.81it/s]
# Caching sequences:  38%|███▊      | 21142/55094 [00:12<00:19, 1748.57it/s]
# Caching sequences:  37%|███▋      | 20348/55094 [00:11<00:19, 1737.68it/s]
# Caching sequences:  39%|███▊      | 21319/55094 [00:12<00:19, 1751.68it/s]
# Caching sequences:  37%|███▋      | 20524/55094 [00:11<00:19, 1743.10it/s]
# Caching sequences:  39%|███▉      | 21495/55094 [00:12<00:19, 1749.16it/s]
# Caching sequences:  38%|███▊      | 20701/55094 [00:11<00:19, 1750.72it/s]
# Caching sequences:  39%|███▉      | 21671/55094 [00:12<00:19, 1751.87it/s]
# Caching sequences:  38%|███▊      | 20877/55094 [00:11<00:19, 1740.41it/s]
# Caching sequences:  40%|███▉      | 21847/55094 [00:12<00:18, 1753.87it/s]
# Caching sequences:  38%|███▊      | 21052/55094 [00:12<00:19, 1738.55it/s]
/s]
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# working on : 100%|██████████| 1/1 [1:44:03<00:00, 6243.38s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.27547-55094.
# hypo.just_sum.shap_hypo_0-30_.0.85.27547-55094.npz
# working on : 100%|██████████| 1/1 [1:44:04<00:00, 6244.42s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.0-27547.
# hypo.just_sum.shap_hypo_0-30_.0.85.0-27547.npz
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.
# hypo.just_sum.shap_hypo_0-30_.0.85.npz
# seq2print_tfbs --count_pt /home/mhorlbec/.cache/scprinter/TFBS_0_conv_v2.pt --foot_pt /home/mhorlbec/.cache/scprinter/TFBS_1_conv_v2.pt --seq_count /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Tcell_1_fold0-gentle-blaze-10.pt_PBMC_bulkATAC_Tcell_1/attr.count.shap_hypo_0_.0.85.bigwig --seq_foot /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Tcell_1_fold0-gentle-blaze-10.pt_PBMC_bulkATAC_Tcell_1/attr.just_sum.shap_hypo_0-30_.0.85.bigwig --genome hg38 --peaks /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/regions_filt.bed --save_name /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/Tcell_1 --gpus 6 7 --collection_name /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/PBMC_bulkATAC_Tcell_1 --post_normalize
# gpu 6
# 100%|██████████| 55094/55094 [00:20<00:00, 2728.08it/s]
# 100%|██████████| 55094/55094 [00:19<00:00, 2800.80it/s]
# (1, 55094, 800)
# /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/Tcell_1
# 100%|██████████| 44365/44365 [00:23<00:00, 1875.80it/s]

# %%
# We first scan TF motifs across all regions to find motif matched sites

# Initialize motif set object
motifs = scp.motifs.FigR_Human_Motifs(genome=printer.genome, bg=[0.25] * 4)

# Prepare motif scanner. Here you can specify which TF motifs you want to scan using tf_genes. If tf_genes=None then use all motifs
motifs.prep_scanner()

# Scan motif sites. This will return the exact genomic coordinates of motif matches
motif_sites = motifs.scan_motif(regions_filt, verbose=True, clean=True)

# Reformat motif matches to a pandas DataFrame
motif_sites = pd.DataFrame(motif_sites)
motif_sites.iloc[:, 2] = motif_sites.iloc[:, 1] + motif_sites.iloc[:, 8]
motif_sites.iloc[:, 1] = motif_sites.iloc[:, 1] + motif_sites.iloc[:, 7]
motif_sites = motif_sites.iloc[:, [0,1,2,4]]
motif_sites.columns=["chrom", "start", "end", "TF"]
# Out:
#   0%|          | 0/110188 [00:00<?, ?it/s]

# %%
# We then extract the TF binding scores at those motif sites
def fetch_bw(args):
    import pyBigWig as pw
    
    TFBS, bw, genome = args
    chroms, starts, ends = np.array(TFBS['chrom']),np.array(TFBS['start']),np.array(TFBS['end'])
    res_all = {}
    with pw.open(bw, 'r') as f:
        for chrom in tqdm(genome.chrom_sizes):
            if chrom == 'chrY':
                continue
            res_all[chrom] = f.values(chrom, 0, genome.chrom_sizes[chrom], numpy=True)
        
    vs = []
    for chr, left, right in zip(tqdm(chroms, mininterval=1), starts, ends):
        vs.append(np.nanmean(res_all[chr][left:right]))
    return vs

# Multi-process loading of TF binding scores 
bigwig_dict = {sample:f"{work_dir}/{sample}_TFBS.bigwig" for sample in samples}
args = [[motif_sites, bigwig_dict[sample], printer.genome] for sample in samples]
n_jobs = 4
import multiprocessing as mp
with mp.Pool(n_jobs) as pool:
    TFBS_scores = list(pool.imap(fetch_bw, args))
TFBS_scores = np.array(TFBS_scores).T
TFBS_scores = pd.DataFrame(TFBS_scores, columns=[f"TFBS_{sample}" for sample in samples])
TFBS_scores = pd.concat([motif_sites, TFBS_scores], axis=1)
# Out:
# /tmp/ipykernel_488059/1126269925.py:16: RuntimeWarning: Mean of empty slice
#   vs.append(np.nanmean(res_all[chr][left:right]))
# /tmp/ipykernel_488059/1126269925.py:16: RuntimeWarning: Mean of empty slice
#   vs.append(np.nanmean(res_all[chr][left:right]))
# /tmp/ipykernel_488059/1126269925.py:16: RuntimeWarning: Mean of empty slice
#   vs.append(np.nanmean(res_all[chr][left:right]))
# /tmp/ipykernel_488059/1126269925.py:16: RuntimeWarning: Mean of empty slice
#   vs.append(np.nanmean(res_all[chr][left:right]))
#   0%|          | 0/24 [00:00<?, ?it/s]
#   0%|          | 0/24 [00:00<?, ?it/s]
#   0%|          | 0/13746109 [00:00<?, ?it/s]
# /tmp/ipykernel_488059/1126269925.py:16: RuntimeWarning: Mean of empty slice
#   vs.append(np.nanmean(res_all[chr][left:right]))
#   0%|          | 0/13746109 [00:00<?, ?it/s]
# /tmp/ipykernel_488059/1126269925.py:16: RuntimeWarning: Mean of empty slice
#   vs.append(np.nanmean(res_all[chr][left:right]))

# %%
TFBS_scores.head()
# Out:
#   chrom   start     end      TF  TFBS_Bcell_0  TFBS_Bcell_1  TFBS_Monocyte_0  \
# 0  chr1  816864  816871    ANHX           NaN           NaN              NaN
# 1  chr1  817181  817188  CREBZF      0.019891      0.023814         0.020551
# 2  chr1  816978  816997   FOXB1      0.022638      0.017177         0.016450
# 3  chr1  817402  817410    GFI1      0.048884      0.046348         0.090971
# 4  chr1  816949  816965   HAND1      0.019428      0.018300         0.015327
#
#    TFBS_Monocyte_1  TFBS_Tcell_0  TFBS_Tcell_1
# 0              NaN           NaN           NaN
# 1         0.039846      0.015211      0.015080
# 2         0.019115      0.019601      0.014479
# 3         0.123267      0.078755      0.067926
# 4         0.021283      0.016531      0.014449

# %%
fig, ax = plt.subplots(2,2, figsize=(7,6))

scores = TFBS_scores.loc[TFBS_scores.TF.values == "CEBPA", :]
ax[0][0].scatter(
    np.mean(scores.loc[:, [f"TFBS_Monocyte_{i}" for i in range(2)]], axis=1), 
    np.mean(scores.loc[:, [f"TFBS_Tcell_{i}" for i in range(2)]], axis=1), s=0.01)
ax[0][0].set_xlabel("Monocyte TFBS")
ax[0][0].set_ylabel("T cell TFBS")
ax[0][0].set_title("CEBPA")
plt.tight_layout()

scores = TFBS_scores.loc[TFBS_scores.TF.values == "SPI1", :]
ax[0][1].scatter(
    np.mean(scores.loc[:, [f"TFBS_Tcell_{i}" for i in range(2)]], axis=1), 
    np.mean(scores.loc[:, [f"TFBS_Bcell_{i}" for i in range(2)]], axis=1), s=0.01)
ax[0][1].set_xlabel("T cell TFBS")
ax[0][1].set_ylabel("B cell TFBS")
ax[0][1].set_title("SPI1")
plt.tight_layout()

scores = TFBS_scores.loc[TFBS_scores.TF.values == "PAX5", :]
ax[1][0].scatter(
    np.mean(scores.loc[:, [f"TFBS_Tcell_{i}" for i in range(2)]], axis=1), 
    np.mean(scores.loc[:, [f"TFBS_Bcell_{i}" for i in range(2)]], axis=1), s=0.01)
ax[1][0].set_xlabel("T cell TFBS")
ax[1][0].set_ylabel("B cell TFBS")
ax[1][0].set_title("PAX5")
plt.tight_layout()

scores = TFBS_scores.loc[TFBS_scores.TF.values == "RUNX3", :]
ax[1][1].scatter(
    np.mean(scores.loc[:, [f"TFBS_Tcell_{i}" for i in range(2)]], axis=1), 
    np.mean(scores.loc[:, [f"TFBS_Bcell_{i}" for i in range(2)]], axis=1), s=0.01)
ax[1][1].set_xlabel("T cell TFBS")
ax[1][1].set_ylabel("B cell TFBS")
ax[1][1].set_title("RUNX3")

plt.show()

# %% [markdown]
# From the above results we clearly see that the model predicts elevated binding of CEBPA in monocytes compared to T cells, as well as higher binding of SPI1 in B cells compared to T cells, higher binding of PAX5 in B cells compared to T cells, and higher binding of RUNX in T cells compared to B cells. From the scatter plot, it was a bit hard to see whether RUNX overall gained binding or lost binding in T cells compared to B cells, so now we calculate the difference of binding at each site, and compare all sites where the absolute value of change is above a certain threhsold (let's do 0.05 for now), and then it becomes clear that RUNX binding is higher in T cells.

# %%
scores = TFBS_scores.loc[TFBS_scores.TF.values == "RUNX3", :]
Tcell_scores = np.mean(scores.loc[:, [f"TFBS_Tcell_{i}" for i in range(2)]], axis=1)
Bcell_scores = np.mean(scores.loc[:, [f"TFBS_Bcell_{i}" for i in range(2)]], axis=1)
diff = Tcell_scores - Bcell_scores
diff = diff[np.abs(diff) > 0.05]
plt.hist(diff, bins=100)
plt.show()

# %% [markdown]
# We hope this tutorial is helpful for you and if you run into any issues please feel free to open a GitHub issue at https://github.com/buenrostrolab/scPrinter!
